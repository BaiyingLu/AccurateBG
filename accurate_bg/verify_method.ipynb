# %%
import argparse
import json
import os

import numpy as np
from cgms_data_seg import CGMSDataSeg
from cnn_ohio import regressor, regressor_transfer, test_ckpt
from data_reader import DataReader

# %%
# --epoch 150 --prediction_horizon 12

epoch = 10
ph = 6
path = "../ohio_results"

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# Load and parse the XML file
tree = ET.parse(r'C:\Users\baiyi\OneDrive\Desktop\BGprediction\OhioT1DM\2018\train\559-ws-training.xml')
root = tree.getroot()

# Create a list to hold the data
data = []

# Initialize a list to hold all event data
data = []


# Loop through each glucose_level element in the patient element
for glucose_level in root.findall('glucose_level'):
    for event in glucose_level.findall('event'):
        # Create a dictionary for each event
        event_data = {
            'ts': event.get('ts'),       # Get timestamp
            'value': float(event.get('value')),  # Get glucose value
            'patient_id': root.get('id'),        # Get patient ID from root
            'weight': float(root.get('weight')),  # Get weight from root
            'insulin_type': root.get('insulin_type')  # Get insulin type from root
        }
        # Add the dictionary to our data list
        data.append(event_data)


# Create a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#                         ts  value patient_id  weight insulin_type
# 0      07-12-2021 01:17:00  101.0        559    99.0      Novalog
# 1      07-12-2021 01:22:00   98.0        559    99.0      Novalog
# 2      07-12-2021 01:27:00  104.0        559    99.0      Novalog
# 3      07-12-2021 01:32:00  112.0        559    99.0      Novalog
# 4      07-12-2021 01:37:00  120.0        559    99.0      Novalog
# ...                    ...    ...        ...     ...          ...
# 10791  17-01-2022 23:36:00  161.0        559    99.0      Novalog
# 10792  17-01-2022 23:41:00  164.0        559    99.0      Novalog
# 10793  17-01-2022 23:46:00  168.0        559    99.0      Novalog
# 10794  17-01-2022 23:51:00  172.0        559    99.0      Novalog
# 10795  17-01-2022 23:56:00  176.0        559    99.0      Novalog
#
# [10796 rows x 5 columns]

# %%
# Before the loop
# ATTENTION: verify the \ or / in different system window or unix
# read in all patients data
pid_2018 = [559, 563, 570, 588, 575, 591]
# pid_2020 = [540, 552, 544, 567, 584, 596]
pid_year = {2018: pid_2018}
# pid_year = {2018: pid_2018, 2020: pid_2020}

train_data = dict()
for year in list(pid_year.keys()):
    pids = pid_year[year]
    for pid in pids:
        reader = DataReader(
            "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/{year}/train/{pid}-ws-training.xml", 5
        )
        train_data[pid] = reader.read()
# add test data of 2018 patient
use_2018_test = False
standard = False  # do not use standard
test_data_2018 = []
for pid in pid_2018:
    reader = DataReader(
        "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/test/{pid}-ws-testing.xml", 5
    )
    test_data_2018 += reader.read()

# a dumb dataset instance
train_dataset = CGMSDataSeg(
    "ohio", "C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/train/559-ws-training.xml", 5
)
sampling_horizon = 12
prediction_horizon = ph
scale = 0.01
outtype = "Same"
# train on training dataset
# k_size, nblock, nn_size, nn_layer, learning_rate, batch_size, epoch, beta
with open(os.path.join(path, "config.json")) as json_file:
    config = json.load(json_file)
argv = (
    config["k_size"],
    config["nblock"],
    config["nn_size"],
    config["nn_layer"],
    config["learning_rate"],
    config["batch_size"],
    epoch,
    config["beta"],
)
l_type = config["loss"]
# test on patients data
outdir = os.path.join(path, f"ph_{prediction_horizon}_{l_type}")
if not os.path.exists(outdir):
    os.makedirs(outdir)
all_errs = []
# Out:
# Reading 44 segments

# %%
# Loop
use_2018_test = False
all_errs = []
for pid in pid_2018:
    train_pids = set(pid_2018) - set([pid])
    local_train_data = []
    if use_2018_test:
        local_train_data += test_data_2018
    for k in train_pids:
        local_train_data += train_data[k]
    print(f"Pretrain data: {sum([sum(x) for x in local_train_data])}")


    train_dataset.data = local_train_data
    train_dataset.set_cutpoint = -1
    train_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        100,
        False,
        outtype,
        1,
        standard,
    )
    regressor(train_dataset, *argv, l_type, outdir)
    # Fine-tune and test
    target_test_dataset = CGMSDataSeg(
        "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/test/{pid}-ws-testing.xml",5
    )
    target_test_dataset.set_cutpoint = 1
    target_test_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        0.01,
        False,
        outtype,
        1,
        standard,
    )
    target_train_dataset = CGMSDataSeg(
        "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/test/{pid}-ws-testing.xml", 5
    )
    target_train_dataset.set_cutpoint = -1
    target_train_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        100,
        False,
        outtype,
        1,
        standard,
    )
    err, labels = test_ckpt(target_test_dataset, outdir)
    errs = [err]
    transfer_res = [labels]
    for i in range(1, 2):
        err, labels = regressor_transfer(
            target_train_dataset,
            target_test_dataset,
            config["batch_size"],
            epoch,
            outdir,
            i,
        )
        errs.append(err)
        transfer_res.append(labels)
    transfer_res = np.concatenate(transfer_res, axis=1)
    np.savetxt(
        f"{outdir}/{pid}.txt",
        transfer_res,
        fmt="%.4f %.4f %.4f %.4f",
    )
    all_errs.append([pid] + errs)
all_errs = np.array(all_errs)
np.savetxt(f"{outdir}/errors.txt", all_errs, fmt="%d %.4f %.4f")
# label pair:(groundTruth, y_pred)
# Out:
# Pretrain data: 9290194.0
# Building dataset, requesting data from 0 to 154
# x here is
# [[116. 117. 119. 116. 111. 110.]
#  [117. 119. 116. 111. 110. 111.]
#  [119. 116. 111. 110. 111. 113.]
#  ...
#  [258. 252. 251. 248. 244. 243.]
#  [252. 251. 248. 244. 243. 244.]
#  [251. 248. 244. 243. 244. 239.]]
# y here is
# [[126. 126. 126. 126. 126. 126.]
#  [131. 131. 131. 131. 131. 131.]
#  [136. 136. 136. 136. 136. 136.]
#  ...
#  [216. 216. 216. 216. 216. 216.]
#  [216. 216. 216. 216. 216. 216.]
#  [213. 213. 213. 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 3578/53194
# Found 154 continuous time series
# Data shape: (56774, 6), Train/test: 56772/2
# Train test ratio: 28386.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# line73: Shape of y: (None, 6)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  887
# Epoch 0, train loss: 0.279557
# Epoch 1, train loss: 0.280114
# Epoch 2, train loss: 0.271940
# Epoch 3, train loss: 0.163924
# Epoch 4, train loss: 0.242374
# Epoch 5, train loss: 0.179918
# WARNING:tensorflow:From C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\training\saver.py:1064: remove_checkpoint (from tensorflow.python.checkpoint.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Epoch 6, train loss: 0.181179
# Epoch 7, train loss: 0.249452
# Epoch 8, train loss: 0.186439
# Epoch 9, train loss: 0.231861
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# x here is
# [[179. 183. 187. 191. 195. 199.]
#  [183. 187. 191. 195. 199. 204.]
#  [187. 191. 195. 199. 204. 209.]
#  ...
#  [188. 187. 186. 186. 186. 187.]
#  [187. 186. 186. 186. 187. 188.]
#  [186. 186. 186. 187. 188. 187.]]
# y here is
# [[215. 215. 215. 215. 215. 215.]
#  [225. 225. 225. 225. 225. 225.]
#  [233. 233. 233. 233. 233. 233.]
#  ...
#  [182. 182. 182. 182. 182. 182.]
#  [180. 180. 180. 180. 180. 180.]
#  [177. 177. 177. 177. 177. 177.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 12 continuous time series
# Data shape: (2382, 6), Train/test: 1/2381
# Train test ratio: 0.00
# ################################################################################
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# x here is
# [[179. 183. 187. 191. 195. 199.]
#  [183. 187. 191. 195. 199. 204.]
#  [187. 191. 195. 199. 204. 209.]
#  ...
#  [188. 187. 186. 186. 186. 187.]
#  [187. 186. 186. 186. 187. 188.]
#  [186. 186. 186. 187. 188. 187.]]
# y here is
# [[215. 215. 215. 215. 215. 215.]
#  [225. 225. 225. 225. 225. 225.]
#  [233. 233. 233. 233. 233. 233.]
#  ...
#  [182. 182. 182. 182. 182. 182.]
#  [180. 180. 180. 180. 180. 180.]
#  [177. 177. 177. 177. 177. 177.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 141/2239
# Found 12 continuous time series
# Data shape: (2382, 6), Train/test: 2380/2
# Train test ratio: 1190.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x000001B86E03B100>
# Epoch 0, test loss: 0.195381
# Epoch 1, test loss: 0.199120
# Epoch 2, test loss: 0.194804
# Epoch 3, test loss: 0.199268
# Epoch 4, test loss: 0.196787
# Epoch 5, test loss: 0.194603
# Epoch 6, test loss: 0.193512
# Epoch 7, test loss: 0.193477
# Epoch 8, test loss: 0.193449
# Epoch 9, test loss: 0.195442
# Pretrain data: 9318765.0
# Building dataset, requesting data from 0 to 176
# x here is
# [[116. 117. 119. 116. 111. 110.]
#  [117. 119. 116. 111. 110. 111.]
#  [119. 116. 111. 110. 111. 113.]
#  ...
#  [258. 252. 251. 248. 244. 243.]
#  [252. 251. 248. 244. 243. 244.]
#  [251. 248. 244. 243. 244. 239.]]
# y here is
# [[126. 126. 126. 126. 126. 126.]
#  [131. 131. 131. 131. 131. 131.]
#  [136. 136. 136. 136. 136. 136.]
#  ...
#  [216. 216. 216. 216. 216. 216.]
#  [216. 216. 216. 216. 216. 216.]
#  [213. 213. 213. 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 3678/51524
# Found 176 continuous time series
# Data shape: (55204, 6), Train/test: 55202/2
# Train test ratio: 27601.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# line73: Shape of y: (None, 6)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  862
# Epoch 0, train loss: 0.307395
# Epoch 1, train loss: 0.175573
# Epoch 2, train loss: 0.186391
# Epoch 3, train loss: 0.208817
# Epoch 4, train loss: 0.187977
# Epoch 5, train loss: 0.203114
# Epoch 6, train loss: 0.221425
# Epoch 7, train loss: 0.194752
# Epoch 8, train loss: 0.165492
# Epoch 9, train loss: 0.193879
# Reading 4 segments
# Building dataset, requesting data from 0 to 4
# x here is
# [[239. 238. 235. 233. 231. 229.]
#  [238. 235. 233. 231. 229. 227.]
#  [235. 233. 231. 229. 227. 222.]
#  ...
#  [140. 151. 154. 152. 151. 149.]
#  [151. 154. 152. 151. 149. 149.]
#  [154. 152. 151. 149. 149. 145.]]
# y here is
# [[208. 208. 208. 208. 208. 208.]
#  [205. 205. 205. 205. 205. 205.]
#  [204. 204. 204. 204. 204. 204.]
#  ...
#  [144. 144. 144. 144. 144. 144.]
#  [140. 140. 140. 140. 140. 140.]
#  [145. 145. 145. 145. 145. 145.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 4 continuous time series
# Data shape: (2526, 6), Train/test: 1/2525
# Train test ratio: 0.00
# ################################################################################
# Reading 4 segments
# Building dataset, requesting data from 0 to 4
# x here is
# [[239. 238. 235. 233. 231. 229.]
#  [238. 235. 233. 231. 229. 227.]
#  [235. 233. 231. 229. 227. 222.]
#  ...
#  [140. 151. 154. 152. 151. 149.]
#  [151. 154. 152. 151. 149. 149.]
#  [154. 152. 151. 149. 149. 145.]]
# y here is
# [[208. 208. 208. 208. 208. 208.]
#  [205. 205. 205. 205. 205. 205.]
#  [204. 204. 204. 204. 204. 204.]
#  ...
#  [144. 144. 144. 144. 144. 144.]
#  [140. 140. 140. 140. 140. 140.]
#  [145. 145. 145. 145. 145. 145.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 54/2470
# Found 4 continuous time series
# Data shape: (2526, 6), Train/test: 2524/2
# Train test ratio: 1262.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x000001B86E2A7D90>
# Epoch 0, test loss: 0.186320
# Epoch 1, test loss: 0.190241
# Epoch 2, test loss: 0.183976
# Epoch 3, test loss: 0.183602
# Epoch 4, test loss: 0.184925
# Epoch 5, test loss: 0.184482
# Epoch 6, test loss: 0.183331
# Epoch 7, test loss: 0.183293
# Epoch 8, test loss: 0.183565
# Epoch 9, test loss: 0.189901
# Pretrain data: 9030756.0
# Building dataset, requesting data from 0 to 177
# x here is
# [[116. 117. 119. 116. 111. 110.]
#  [117. 119. 116. 111. 110. 111.]
#  [119. 116. 111. 110. 111. 113.]
#  ...
#  [258. 252. 251. 248. 244. 243.]
#  [252. 251. 248. 244. 243. 244.]
#  [251. 248. 244. 243. 244. 239.]]
# y here is
# [[126. 126. 126. 126. 126. 126.]
#  [131. 131. 131. 131. 131. 131.]
#  [136. 136. 136. 136. 136. 136.]
#  ...
#  [216. 216. 216. 216. 216. 216.]
#  [216. 216. 216. 216. 216. 216.]
#  [213. 213. 213. 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 3951/52382
# Found 177 continuous time series
# Data shape: (56335, 6), Train/test: 56333/2
# Train test ratio: 28166.50
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# line73: Shape of y: (None, 6)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  880
# Epoch 0, train loss: 0.337083
# Epoch 1, train loss: 0.212394
# Epoch 2, train loss: 0.161713
# Epoch 3, train loss: 0.176315
# Epoch 4, train loss: 0.232324
# Epoch 5, train loss: 0.224416
# Epoch 6, train loss: 0.199171
# Epoch 7, train loss: 0.172310
# Epoch 8, train loss: 0.293664
# Epoch 9, train loss: 0.181995
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# x here is
# [[135. 143. 152. 159. 166. 172.]
#  [143. 152. 159. 166. 172. 178.]
#  [152. 159. 166. 172. 178. 184.]
#  ...
#  [203. 205. 208. 204. 202. 201.]
#  [205. 208. 204. 202. 201. 201.]
#  [208. 204. 202. 201. 201. 201.]]
# y here is
# [[203. 203. 203. 203. 203. 203.]
#  [204. 204. 204. 204. 204. 204.]
#  [205. 205. 205. 205. 205. 205.]
#  ...
#  [212. 212. 212. 212. 212. 212.]
#  [218. 218. 218. 218. 218. 218.]
#  [224. 224. 224. 224. 224. 224.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (2635, 6), Train/test: 1/2634
# Train test ratio: 0.00
# ################################################################################
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# x here is
# [[135. 143. 152. 159. 166. 172.]
#  [143. 152. 159. 166. 172. 178.]
#  [152. 159. 166. 172. 178. 184.]
#  ...
#  [203. 205. 208. 204. 202. 201.]
#  [205. 208. 204. 202. 201. 201.]
#  [208. 204. 202. 201. 201. 201.]]
# y here is
# [[203. 203. 203. 203. 203. 203.]
#  [204. 204. 204. 204. 204. 204.]
#  [205. 205. 205. 205. 205. 205.]
#  ...
#  [212. 212. 212. 212. 212. 212.]
#  [218. 218. 218. 218. 218. 218.]
#  [224. 224. 224. 224. 224. 224.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 27/2606
# Found 10 continuous time series
# Data shape: (2635, 6), Train/test: 2633/2
# Train test ratio: 1316.50
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x000001B86C0D2710>
# Epoch 0, test loss: 0.161688
# Epoch 1, test loss: 0.161967
# Epoch 2, test loss: 0.164903
# Epoch 3, test loss: 0.161685
# Epoch 4, test loss: 0.165777
# Epoch 5, test loss: 0.165356
# Epoch 6, test loss: 0.158797
# Epoch 7, test loss: 0.162457
# Epoch 8, test loss: 0.161822
# Epoch 9, test loss: 0.158961
# Pretrain data: 9004352.0
# Building dataset, requesting data from 0 to 187
# x here is
# [[160. 158. 160. 166. 175. 182.]
#  [158. 160. 166. 175. 182. 188.]
#  [160. 166. 175. 182. 188. 192.]
#  ...
#  [258. 252. 251. 248. 244. 243.]
#  [252. 251. 248. 244. 243. 244.]
#  [251. 248. 244. 243. 244. 239.]]
# y here is
# [[218. 218. 218. 218. 218. 218.]
#  [226. 226. 226. 226. 226. 226.]
#  [231. 231. 231. 231. 231. 231.]
#  ...
#  [216. 216. 216. 216. 216. 216.]
#  [216. 216. 216. 216. 216. 216.]
#  [213. 213. 213. 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 4084/50478
# Found 187 continuous time series
# Data shape: (54564, 6), Train/test: 54562/2
# Train test ratio: 27281.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# line73: Shape of y: (None, 6)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  852
# Epoch 0, train loss: 0.242159
# Epoch 1, train loss: 0.203722
# Epoch 2, train loss: 0.179449
# Epoch 3, train loss: 0.229244
# Epoch 4, train loss: 0.214231
# Epoch 5, train loss: 0.220016
# Epoch 6, train loss: 0.193414
# Epoch 7, train loss: 0.204642
# Epoch 8, train loss: 0.250442
# Epoch 9, train loss: 0.217186
# Reading 3 segments
# Building dataset, requesting data from 0 to 3
# x here is
# [[127. 123. 118. 112. 108. 106.]
#  [123. 118. 112. 108. 106. 103.]
#  [118. 112. 108. 106. 103.  98.]
#  ...
#  [238. 243. 250. 254. 263. 280.]
#  [243. 250. 254. 263. 280. 288.]
#  [250. 254. 263. 280. 288. 301.]]
# y here is
# [[ 89.  89.  89.  89.  89.  89.]
#  [ 87.  87.  87.  87.  87.  87.]
#  [ 85.  85.  85.  85.  85.  85.]
#  ...
#  [307. 307. 307. 307. 307. 307.]
#  [311. 311. 311. 311. 311. 311.]
#  [321. 321. 321. 321. 321. 321.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 3 continuous time series
# Data shape: (2758, 6), Train/test: 1/2757
# Train test ratio: 0.00
# ################################################################################
# Reading 3 segments
# Building dataset, requesting data from 0 to 3
# x here is
# [[127. 123. 118. 112. 108. 106.]
#  [123. 118. 112. 108. 106. 103.]
#  [118. 112. 108. 106. 103.  98.]
#  ...
#  [238. 243. 250. 254. 263. 280.]
#  [243. 250. 254. 263. 280. 288.]
#  [250. 254. 263. 280. 288. 301.]]
# y here is
# [[ 89.  89.  89.  89.  89.  89.]
#  [ 87.  87.  87.  87.  87.  87.]
#  [ 85.  85.  85.  85.  85.  85.]
#  ...
#  [307. 307. 307. 307. 307. 307.]
#  [311. 311. 311. 311. 311. 311.]
#  [321. 321. 321. 321. 321. 321.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 15/2741
# Found 3 continuous time series
# Data shape: (2758, 6), Train/test: 2756/2
# Train test ratio: 1378.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x000001B86E1DC2B0>
# Epoch 0, test loss: 0.185889
# Epoch 1, test loss: 0.186196
# Epoch 2, test loss: 0.185975
# Epoch 3, test loss: 0.185660
# Epoch 4, test loss: 0.185400
# Epoch 5, test loss: 0.185577
# Epoch 6, test loss: 0.185561
# Epoch 7, test loss: 0.185429
# Epoch 8, test loss: 0.185704
# Epoch 9, test loss: 0.185945
# Pretrain data: 9407520.0
# Building dataset, requesting data from 0 to 125
# x here is
# [[116. 117. 119. 116. 111. 110.]
#  [117. 119. 116. 111. 110. 111.]
#  [119. 116. 111. 110. 111. 113.]
#  ...
#  [ 71.  73.  74.  74.  76.  79.]
#  [ 73.  74.  74.  76.  79.  87.]
#  [ 74.  74.  76.  79.  87.  95.]]
# y here is
# [[126. 126. 126. 126. 126. 126.]
#  [131. 131. 131. 131. 131. 131.]
#  [136. 136. 136. 136. 136. 136.]
#  ...
#  [120. 120. 120. 120. 120. 120.]
#  [123. 123. 123. 123. 123. 123.]
#  [128. 128. 128. 128. 128. 128.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 2931/53088
# Found 125 continuous time series
# Data shape: (56021, 6), Train/test: 56019/2
# Train test ratio: 28009.50
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# line73: Shape of y: (None, 6)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  875
# Epoch 0, train loss: 0.260458
# Epoch 1, train loss: 0.251406
# Epoch 2, train loss: 0.173431
# Epoch 3, train loss: 0.130146
# Epoch 4, train loss: 0.249841
# Epoch 5, train loss: 0.245569
# Epoch 6, train loss: 0.275889
# Epoch 7, train loss: 0.221224
# Epoch 8, train loss: 0.200347
# Epoch 9, train loss: 0.234846
# Reading 11 segments
# Building dataset, requesting data from 0 to 11
# x here is
# [[214. 217. 217. 212. 209. 208.]
#  [217. 217. 212. 209. 208. 209.]
#  [217. 212. 209. 208. 209. 209.]
#  ...
#  [128. 124. 126. 128. 130. 124.]
#  [124. 126. 128. 130. 124. 120.]
#  [126. 128. 130. 124. 120. 117.]]
# y here is
# [[190. 190. 190. 190. 190. 190.]
#  [183. 183. 183. 183. 183. 183.]
#  [179. 179. 179. 179. 179. 179.]
#  ...
#  [129. 129. 129. 129. 129. 129.]
#  [139. 139. 139. 139. 139. 139.]
#  [157. 157. 157. 157. 157. 157.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 11 continuous time series
# Data shape: (2469, 6), Train/test: 1/2468
# Train test ratio: 0.00
# ################################################################################
# Reading 11 segments
# Building dataset, requesting data from 0 to 11
# x here is
# [[214. 217. 217. 212. 209. 208.]
#  [217. 217. 212. 209. 208. 209.]
#  [217. 212. 209. 208. 209. 209.]
#  ...
#  [128. 124. 126. 128. 130. 124.]
#  [124. 126. 128. 130. 124. 120.]
#  [126. 128. 130. 124. 120. 117.]]
# y here is
# [[190. 190. 190. 190. 190. 190.]
#  [183. 183. 183. 183. 183. 183.]
#  [179. 179. 179. 179. 179. 179.]
#  ...
#  [129. 129. 129. 129. 129. 129.]
#  [139. 139. 139. 139. 139. 139.]
#  [157. 157. 157. 157. 157. 157.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 247/2220
# Found 11 continuous time series
# Data shape: (2469, 6), Train/test: 2467/2
# Train test ratio: 1233.50
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x000001B86BA10970>
# Epoch 0, test loss: 0.237076
# Epoch 1, test loss: 0.242734
# Epoch 2, test loss: 0.235810
# Epoch 3, test loss: 0.237538
# Epoch 4, test loss: 0.235985
# Epoch 5, test loss: 0.234361
# Epoch 6, test loss: 0.235188
# Epoch 7, test loss: 0.235626
# Epoch 8, test loss: 0.234762
# Epoch 9, test loss: 0.233785
# Pretrain data: 9397433.0
# Building dataset, requesting data from 0 to 171
# x here is
# [[116. 117. 119. 116. 111. 110.]
#  [117. 119. 116. 111. 110. 111.]
#  [119. 116. 111. 110. 111. 113.]
#  ...
#  [258. 252. 251. 248. 244. 243.]
#  [252. 251. 248. 244. 243. 244.]
#  [251. 248. 244. 243. 244. 239.]]
# y here is
# [[126. 126. 126. 126. 126. 126.]
#  [131. 131. 131. 131. 131. 131.]
#  [136. 136. 136. 136. 136. 136.]
#  ...
#  [216. 216. 216. 216. 216. 216.]
#  [216. 216. 216. 216. 216. 216.]
#  [213. 213. 213. 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 3633/52897
# Found 171 continuous time series
# Data shape: (56532, 6), Train/test: 56530/2
# Train test ratio: 28265.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# line73: Shape of y: (None, 6)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  883
# Epoch 0, train loss: 0.307747
# Epoch 1, train loss: 0.205393
# Epoch 2, train loss: 0.167534
# Epoch 3, train loss: 0.215189
# Epoch 4, train loss: 0.193405
# Epoch 5, train loss: 0.192382
# Epoch 6, train loss: 0.215615
# Epoch 7, train loss: 0.196680
# Epoch 8, train loss: 0.266562
# Epoch 9, train loss: 0.199693
# Reading 5 segments
# Building dataset, requesting data from 0 to 5
# x here is
# [[283. 282. 281. 277. 267. 258.]
#  [282. 281. 277. 267. 258. 251.]
#  [281. 277. 267. 258. 251. 237.]
#  ...
#  [164. 163. 160. 159. 159. 156.]
#  [163. 160. 159. 159. 156. 154.]
#  [160. 159. 159. 156. 154. 152.]]
# y here is
# [[201. 201. 201. 201. 201. 201.]
#  [195. 195. 195. 195. 195. 195.]
#  [189. 189. 189. 189. 189. 189.]
#  ...
#  [151. 151. 151. 151. 151. 151.]
#  [149. 149. 149. 149. 149. 149.]
#  [144. 144. 144. 144. 144. 144.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 5 continuous time series
# Data shape: (2705, 6), Train/test: 1/2704
# Train test ratio: 0.00
# ################################################################################
# Reading 5 segments
# Building dataset, requesting data from 0 to 5
# x here is
# [[283. 282. 281. 277. 267. 258.]
#  [282. 281. 277. 267. 258. 251.]
#  [281. 277. 267. 258. 251. 237.]
#  ...
#  [164. 163. 160. 159. 159. 156.]
#  [163. 160. 159. 159. 156. 154.]
#  [160. 159. 159. 156. 154. 152.]]
# y here is
# [[201. 201. 201. 201. 201. 201.]
#  [195. 195. 195. 195. 195. 195.]
#  [189. 189. 189. 189. 189. 189.]
#  ...
#  [151. 151. 151. 151. 151. 151.]
#  [149. 149. 149. 149. 149. 149.]
#  [144. 144. 144. 144. 144. 144.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 249/2454
# Found 5 continuous time series
# Data shape: (2705, 6), Train/test: 2703/2
# Train test ratio: 1351.50
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x000001B86BFEBFD0>
# Epoch 0, test loss: 0.217939
# Epoch 1, test loss: 0.211483
# Epoch 2, test loss: 0.210557
# Epoch 3, test loss: 0.211178
# Epoch 4, test loss: 0.210636
# Epoch 5, test loss: 0.211013
# Epoch 6, test loss: 0.211599
# Epoch 7, test loss: 0.210553
# Epoch 8, test loss: 0.210244
# Epoch 9, test loss: 0.210405

# %%
all_errs
# Out:
# array([[5.59000000e+02, 1.96096092e-01, 1.95441991e-01],
#        [5.63000000e+02, 1.86664909e-01, 1.89901307e-01],
#        [5.70000000e+02, 1.64349169e-01, 1.58961207e-01],
#        [5.88000000e+02, 1.89570844e-01, 1.85944960e-01],
#        [5.75000000e+02, 2.38005698e-01, 2.33785048e-01],
#        [5.91000000e+02, 2.12123454e-01, 2.10404932e-01]])

# %%
# Convert the second and third columns to floats
second_column = all_errs[:, 1].astype(float)
third_column = all_errs[:, 2].astype(float)

# Calculate the average
average_second_column = np.mean(second_column)
average_third_column = np.mean(third_column)

print("Average of the second column:", average_second_column)
print("Average of the third column:", average_third_column)
# Out:
# Average of the second column: 0.19780169427394867
# Average of the third column: 0.19573990752299628

# %%
[5.59000000e+02, 1.96096092e-01, 1.95441991e-01],
[5.63000000e+02, 1.86664909e-01, 1.89901307e-01],
[5.70000000e+02, 1.64349169e-01, 1.58961207e-01],
[5.88000000e+02, 1.89570844e-01, 1.85944960e-01],
[5.75000000e+02, 2.38005698e-01, 2.33785048e-01],
[5.91000000e+02, 2.12123454e-01, 2.10404932e-01]

# %%
array([[5.59000000e+02, 1.96724802e-01, 1.91919029e-01],
       [5.63000000e+02, 1.92446381e-01, 1.88920885e-01],
       [5.70000000e+02, 1.69331595e-01, 1.68061674e-01],
       [5.88000000e+02, 1.91239759e-01, 1.88654602e-01],
       [5.75000000e+02, 2.39297733e-01, 2.37169400e-01],
       [5.91000000e+02, 2.16453165e-01, 2.14432269e-01]]) # 60min

# %%
# Convert the second and third columns to floats
second_column = all_errs[:, 1].astype(float)
third_column = all_errs[:, 2].astype(float)

# Calculate the average
average_second_column = np.mean(second_column)
average_third_column = np.mean(third_column)

print("Average of the second column:", average_second_column)
print("Average of the third column:", average_third_column)
# Out:
# Average of the second column: 0.20091557254393896
# Average of the third column: 0.19819297641515732

# %%
target_train_dataset

# %% [markdown]
# # Look at it before fine tuning

# %%
use_2018_test = False
all_errs = []
for pid in pid_2018:
    train_pids = set(pid_2018) - set([pid])
    local_train_data = []
    if use_2018_test:
        local_train_data += test_data_2018
    for k in train_pids:
        local_train_data += train_data[k]
    print(f"Pretrain data: {sum([sum(x) for x in local_train_data])}")

    train_dataset.data = local_train_data
    train_dataset.set_cutpoint = -1
    train_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        100,
        False,
        outtype,
        1,
        standard,
    )
    regressor(train_dataset, *argv, l_type, outdir)

    # Test before fine-tuning
    target_test_dataset = CGMSDataSeg(
        "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/test/{pid}-ws-testing.xml", 5
    )
    target_test_dataset.set_cutpoint = 1
    target_test_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        0.01,
        False,
        outtype,
        1,
        standard,
    )

    # Record error before fine-tuning
    pre_fine_tune_err, pre_fine_tune_labels = test_ckpt(target_test_dataset, outdir)
    errs = [pre_fine_tune_err]  # Initialize the error list with the error before fine-tuning
    transfer_res = [pre_fine_tune_labels]

    # Fine-tune and test
    target_train_dataset = CGMSDataSeg(
        "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/train/{pid}-ws-training.xml", 5
    )
    target_train_dataset.set_cutpoint = -1
    target_train_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        100,
        False,
        outtype,
        1,
        standard,
    )

    for i in range(1, 2):
        err, labels = regressor_transfer(
            target_train_dataset,
            target_test_dataset,
            config["batch_size"],
            epoch,
            outdir,
            i,
        )
        errs.append(err)
        transfer_res.append(labels)

    transfer_res = np.concatenate(transfer_res, axis=1)
    np.savetxt(
        f"{outdir}/{pid}.txt",
        transfer_res,
        fmt="%.4f %.4f %.4f %.4f",
    )
    all_errs.append([pid] + errs)

all_errs = np.array(all_errs)
np.savetxt(f"{outdir}/no_fine_tune_errors.txt", all_errs, fmt="%d %.4f %.4f")
# Out:
# Pretrain data: 9290194.0
# Building dataset, requesting data from 0 to 154
# x here is
# [[116. 117. 119. ... 117. 121. 126.]
#  [117. 119. 116. ... 121. 126. 131.]
#  [119. 116. 111. ... 126. 131. 136.]
#  ...
#  [323. 328. 264. ... 248. 244. 243.]
#  [328. 264. 264. ... 244. 243. 244.]
#  [264. 264. 264. ... 243. 244. 239.]]
# y here is
# [[149. 149. 149. ... 149. 149. 149.]
#  [149. 149. 149. ... 149. 149. 149.]
#  [151. 151. 151. ... 151. 151. 151.]
#  ...
#  [216. 216. 216. ... 216. 216. 216.]
#  [216. 216. 216. ... 216. 216. 216.]
#  [213. 213. 213. ... 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 3530/52336
# Found 154 continuous time series
# Data shape: (55868, 12), Train/test: 55866/2
# Train test ratio: 27933.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 12), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 12), dtype=float32)
# line73: Shape of y: (None, 12)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  872
# Epoch 0, train loss: 0.220874
# Epoch 1, train loss: 0.234388
# Epoch 2, train loss: 0.216487
# Epoch 3, train loss: 0.258476
# Epoch 4, train loss: 0.196587
# Epoch 5, train loss: 0.184257
# Epoch 6, train loss: 0.192160
# Epoch 7, train loss: 0.199246
# Epoch 8, train loss: 0.151904
# Epoch 9, train loss: 0.239466
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# x here is
# [[179. 183. 187. ... 211. 211. 215.]
#  [183. 187. 191. ... 211. 215. 225.]
#  [187. 191. 195. ... 215. 225. 233.]
#  ...
#  [179. 181. 182. ... 186. 186. 187.]
#  [181. 182. 184. ... 186. 187. 188.]
#  [182. 184. 187. ... 187. 188. 187.]]
# y here is
# [[248. 248. 248. ... 248. 248. 248.]
#  [250. 250. 250. ... 250. 250. 250.]
#  [252. 252. 252. ... 252. 252. 252.]
#  ...
#  [182. 182. 182. ... 182. 182. 182.]
#  [180. 180. 180. ... 180. 180. 180.]
#  [177. 177. 177. ... 177. 177. 177.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 12 continuous time series
# Data shape: (2310, 12), Train/test: 1/2309
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# Reading 44 segments
# Building dataset, requesting data from 0 to 44
# x here is
# [[101.  98. 104. ... 145. 148. 151.]
#  [ 98. 104. 112. ... 148. 151. 150.]
#  [104. 112. 120. ... 151. 150. 124.]
#  ...
#  [143. 144. 145. ... 149. 150. 152.]
#  [144. 145. 147. ... 150. 152. 155.]
#  [145. 147. 148. ... 152. 155. 156.]]
# y here is
# [[115. 115. 115. ... 115. 115. 115.]
#  [111. 111. 111. ... 111. 111. 111.]
#  [109. 109. 109. ... 109. 109. 109.]
#  ...
#  [168. 168. 168. ... 168. 168. 168.]
#  [172. 172. 172. ... 172. 172. 172.]
#  [176. 176. 176. ... 176. 176. 176.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 773/9273
# Found 44 continuous time series
# Data shape: (10048, 12), Train/test: 10046/2
# Train test ratio: 5023.00
# ################################################################################
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# x here is
# [[179. 183. 187. ... 211. 211. 215.]
#  [183. 187. 191. ... 211. 215. 225.]
#  [187. 191. 195. ... 215. 225. 233.]
#  ...
#  [179. 181. 182. ... 186. 186. 187.]
#  [181. 182. 184. ... 186. 187. 188.]
#  [182. 184. 187. ... 187. 188. 187.]]
# y here is
# [[248. 248. 248. ... 248. 248. 248.]
#  [250. 250. 250. ... 250. 250. 250.]
#  [252. 252. 252. ... 252. 252. 252.]
#  ...
#  [182. 182. 182. ... 182. 182. 182.]
#  [180. 180. 180. ... 180. 180. 180.]
#  [177. 177. 177. ... 177. 177. 177.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 12 continuous time series
# Data shape: (2310, 12), Train/test: 1/2309
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x00000235BC478970>
# Epoch 0, test loss: 0.196575
# Epoch 1, test loss: 0.194630
# Epoch 2, test loss: 0.213264
# Epoch 3, test loss: 0.202337
# Epoch 4, test loss: 0.193927
# Epoch 5, test loss: 0.195760
# Epoch 6, test loss: 0.194468
# Epoch 7, test loss: 0.204128
# Epoch 8, test loss: 0.193820
# Epoch 9, test loss: 0.196520
# Pretrain data: 9318765.0
# Building dataset, requesting data from 0 to 176
# x here is
# [[116. 117. 119. ... 117. 121. 126.]
#  [117. 119. 116. ... 121. 126. 131.]
#  [119. 116. 111. ... 126. 131. 136.]
#  ...
#  [323. 328. 264. ... 248. 244. 243.]
#  [328. 264. 264. ... 244. 243. 244.]
#  [264. 264. 264. ... 243. 244. 239.]]
# y here is
# [[149. 149. 149. ... 149. 149. 149.]
#  [149. 149. 149. ... 149. 149. 149.]
#  [151. 151. 151. ... 151. 151. 151.]
#  ...
#  [216. 216. 216. ... 216. 216. 216.]
#  [216. 216. 216. ... 216. 216. 216.]
#  [213. 213. 213. ... 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 3620/50544
# Found 176 continuous time series
# Data shape: (54166, 12), Train/test: 54164/2
# Train test ratio: 27082.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 12), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 12), dtype=float32)
# line73: Shape of y: (None, 12)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  846
# Epoch 0, train loss: 0.248444
# Epoch 1, train loss: 0.238657
# Epoch 2, train loss: 0.326950
# Epoch 3, train loss: 0.205621
# Epoch 4, train loss: 0.165528
# Epoch 5, train loss: 0.271478
# Epoch 6, train loss: 0.176788
# Epoch 7, train loss: 0.342651
# Epoch 8, train loss: 0.191966
# Epoch 9, train loss: 0.287010
# Reading 4 segments
# Building dataset, requesting data from 0 to 4
# x here is
# [[239. 238. 235. ... 216. 210. 208.]
#  [238. 235. 233. ... 210. 208. 205.]
#  [235. 233. 231. ... 208. 205. 204.]
#  ...
#  [144. 145. 145. ... 152. 151. 149.]
#  [145. 145. 145. ... 151. 149. 149.]
#  [145. 145. 143. ... 149. 149. 145.]]
# y here is
# [[202. 202. 202. ... 202. 202. 202.]
#  [203. 203. 203. ... 203. 203. 203.]
#  [203. 203. 203. ... 203. 203. 203.]
#  ...
#  [144. 144. 144. ... 144. 144. 144.]
#  [140. 140. 140. ... 140. 140. 140.]
#  [145. 145. 145. ... 145. 145. 145.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 4 continuous time series
# Data shape: (2502, 12), Train/test: 1/2501
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# Reading 22 segments
# Building dataset, requesting data from 0 to 22
# x here is
# [[219. 229. 224. ... 196. 208. 202.]
#  [229. 224. 221. ... 208. 202. 192.]
#  [224. 221. 215. ... 202. 192. 194.]
#  ...
#  [201. 204. 205. ... 237. 241. 243.]
#  [204. 205. 209. ... 241. 243. 251.]
#  [205. 209. 216. ... 243. 251. 257.]]
# y here is
# [[183. 183. 183. ... 183. 183. 183.]
#  [172. 172. 172. ... 172. 172. 172.]
#  [166. 166. 166. ... 166. 166. 166.]
#  ...
#  [250. 250. 250. ... 250. 250. 250.]
#  [246. 246. 246. ... 246. 246. 246.]
#  [240. 240. 240. ... 240. 240. 240.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 683/11065
# Found 22 continuous time series
# Data shape: (11750, 12), Train/test: 11748/2
# Train test ratio: 5874.00
# ################################################################################
# Reading 4 segments
# Building dataset, requesting data from 0 to 4
# x here is
# [[239. 238. 235. ... 216. 210. 208.]
#  [238. 235. 233. ... 210. 208. 205.]
#  [235. 233. 231. ... 208. 205. 204.]
#  ...
#  [144. 145. 145. ... 152. 151. 149.]
#  [145. 145. 145. ... 151. 149. 149.]
#  [145. 145. 143. ... 149. 149. 145.]]
# y here is
# [[202. 202. 202. ... 202. 202. 202.]
#  [203. 203. 203. ... 203. 203. 203.]
#  [203. 203. 203. ... 203. 203. 203.]
#  ...
#  [144. 144. 144. ... 144. 144. 144.]
#  [140. 140. 140. ... 140. 140. 140.]
#  [145. 145. 145. ... 145. 145. 145.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 4 continuous time series
# Data shape: (2502, 12), Train/test: 1/2501
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x00000235BD80A140>
# Epoch 0, test loss: 0.197053
# Epoch 1, test loss: 0.192090
# Epoch 2, test loss: 0.193768
# Epoch 3, test loss: 0.192736
# Epoch 4, test loss: 0.192894
# Epoch 5, test loss: 0.207373
# Epoch 6, test loss: 0.193864
# Epoch 7, test loss: 0.191793
# Epoch 8, test loss: 0.194261
# Epoch 9, test loss: 0.196037
# Pretrain data: 9030756.0
# Building dataset, requesting data from 0 to 177
# x here is
# [[116. 117. 119. ... 117. 121. 126.]
#  [117. 119. 116. ... 121. 126. 131.]
#  [119. 116. 111. ... 126. 131. 136.]
#  ...
#  [323. 328. 264. ... 248. 244. 243.]
#  [328. 264. 264. ... 244. 243. 244.]
#  [264. 264. 264. ... 243. 244. 239.]]
# y here is
# [[149. 149. 149. ... 149. 149. 149.]
#  [149. 149. 149. ... 149. 149. 149.]
#  [151. 151. 151. ... 151. 151. 151.]
#  ...
#  [216. 216. 216. ... 216. 216. 216.]
#  [216. 216. 216. ... 216. 216. 216.]
#  [213. 213. 213. ... 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 3883/51406
# Found 177 continuous time series
# Data shape: (55291, 12), Train/test: 55289/2
# Train test ratio: 27644.50
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 12), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 12), dtype=float32)
# line73: Shape of y: (None, 12)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  863
# Epoch 0, train loss: 0.169704
# Epoch 1, train loss: 0.255045
# Epoch 2, train loss: 0.219954
# Epoch 3, train loss: 0.175570
# Epoch 4, train loss: 0.277502
# Epoch 5, train loss: 0.163411
# Epoch 6, train loss: 0.226924
# Epoch 7, train loss: 0.217204
# Epoch 8, train loss: 0.225264
# Epoch 9, train loss: 0.237733
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# x here is
# [[135. 143. 152. ... 195. 199. 203.]
#  [143. 152. 159. ... 199. 203. 204.]
#  [152. 159. 166. ... 203. 204. 205.]
#  ...
#  [187. 190. 192. ... 204. 202. 201.]
#  [190. 192. 194. ... 202. 201. 201.]
#  [192. 194. 197. ... 201. 201. 201.]]
# y here is
# [[223. 223. 223. ... 223. 223. 223.]
#  [222. 222. 222. ... 222. 222. 222.]
#  [220. 220. 220. ... 220. 220. 220.]
#  ...
#  [212. 212. 212. ... 212. 212. 212.]
#  [218. 218. 218. ... 218. 218. 218.]
#  [224. 224. 224. ... 224. 224. 224.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (2575, 12), Train/test: 1/2574
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# Reading 21 segments
# Building dataset, requesting data from 0 to 21
# x here is
# [[101. 100. 100. ...  90.  87.  86.]
#  [100. 100.  99. ...  87.  86.  85.]
#  [100.  99.  98. ...  86.  85.  85.]
#  ...
#  [ 68.  68.  69. ...  74.  76.  79.]
#  [ 68.  69.  69. ...  76.  79.  87.]
#  [ 69.  69.  69. ...  79.  87.  95.]]
# y here is
# [[ 86.  86.  86. ...  86.  86.  86.]
#  [ 85.  85.  85. ...  85.  85.  85.]
#  [ 83.  83.  83. ...  83.  83.  83.]
#  ...
#  [120. 120. 120. ... 120. 120. 120.]
#  [123. 123. 123. ... 123. 123. 123.]
#  [128. 128. 128. ... 128. 128. 128.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 420/10203
# Found 21 continuous time series
# Data shape: (10625, 12), Train/test: 10623/2
# Train test ratio: 5311.50
# ################################################################################
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# x here is
# [[135. 143. 152. ... 195. 199. 203.]
#  [143. 152. 159. ... 199. 203. 204.]
#  [152. 159. 166. ... 203. 204. 205.]
#  ...
#  [187. 190. 192. ... 204. 202. 201.]
#  [190. 192. 194. ... 202. 201. 201.]
#  [192. 194. 197. ... 201. 201. 201.]]
# y here is
# [[223. 223. 223. ... 223. 223. 223.]
#  [222. 222. 222. ... 222. 222. 222.]
#  [220. 220. 220. ... 220. 220. 220.]
#  ...
#  [212. 212. 212. ... 212. 212. 212.]
#  [218. 218. 218. ... 218. 218. 218.]
#  [224. 224. 224. ... 224. 224. 224.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (2575, 12), Train/test: 1/2574
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x00000235BD753D00>
# Epoch 0, test loss: 0.161437
# Epoch 1, test loss: 0.162121
# Epoch 2, test loss: 0.162651
# Epoch 3, test loss: 0.161537
# Epoch 4, test loss: 0.175689
# Epoch 5, test loss: 0.160912
# Epoch 6, test loss: 0.160949
# Epoch 7, test loss: 0.161374
# Epoch 8, test loss: 0.162961
# Epoch 9, test loss: 0.170069
# Pretrain data: 9004352.0
# Building dataset, requesting data from 0 to 187
# x here is
# [[160. 158. 160. ... 192. 201. 218.]
#  [158. 160. 166. ... 201. 218. 226.]
#  [160. 166. 175. ... 218. 226. 231.]
#  ...
#  [323. 328. 264. ... 248. 244. 243.]
#  [328. 264. 264. ... 244. 243. 244.]
#  [264. 264. 264. ... 243. 244. 239.]]
# y here is
# [[246. 246. 246. ... 246. 246. 246.]
#  [259. 259. 259. ... 259. 259. 259.]
#  [269. 269. 269. ... 269. 269. 269.]
#  ...
#  [216. 216. 216. ... 216. 216. 216.]
#  [216. 216. 216. ... 216. 216. 216.]
#  [213. 213. 213. ... 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 4019/49433
# Found 187 continuous time series
# Data shape: (53454, 12), Train/test: 53452/2
# Train test ratio: 26726.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 12), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 12), dtype=float32)
# line73: Shape of y: (None, 12)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  835
# Epoch 0, train loss: 0.300263
# Epoch 1, train loss: 0.221376
# Epoch 2, train loss: 0.335485
# Epoch 3, train loss: 0.200581
# Epoch 4, train loss: 0.212905
# Epoch 5, train loss: 0.173982
# Epoch 6, train loss: 0.180019
# Epoch 7, train loss: 0.170209
# Epoch 8, train loss: 0.210224
# Epoch 9, train loss: 0.218291
# Reading 3 segments
# Building dataset, requesting data from 0 to 3
# x here is
# [[127. 123. 118. ...  93.  93.  89.]
#  [123. 118. 112. ...  93.  89.  87.]
#  [118. 112. 108. ...  89.  87.  85.]
#  ...
#  [182. 191. 203. ... 254. 263. 280.]
#  [191. 203. 215. ... 263. 280. 288.]
#  [203. 215. 223. ... 280. 288. 301.]]
# y here is
# [[ 76.  76.  76. ...  76.  76.  76.]
#  [ 74.  74.  74. ...  74.  74.  74.]
#  [ 83.  83.  83. ...  83.  83.  83.]
#  ...
#  [307. 307. 307. ... 307. 307. 307.]
#  [311. 311. 311. ... 311. 311. 311.]
#  [321. 321. 321. ... 321. 321. 321.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 1/0
# Found 3 continuous time series
# Data shape: (2740, 12), Train/test: 1/2739
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# Reading 11 segments
# Building dataset, requesting data from 0 to 11
# x here is
# [[116. 117. 119. ... 117. 121. 126.]
#  [117. 119. 116. ... 121. 126. 131.]
#  [119. 116. 111. ... 126. 131. 136.]
#  ...
#  [218. 214. 212. ... 180. 175. 171.]
#  [214. 212. 211. ... 175. 171. 168.]
#  [212. 211. 207. ... 171. 168. 162.]]
# y here is
# [[149. 149. 149. ... 149. 149. 149.]
#  [149. 149. 149. ... 149. 149. 149.]
#  [151. 151. 151. ... 151. 151. 151.]
#  ...
#  [140. 140. 140. ... 140. 140. 140.]
#  [137. 137. 137. ... 137. 137. 137.]
#  [132. 132. 132. ... 132. 132. 132.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 284/12176
# Found 11 continuous time series
# Data shape: (12462, 12), Train/test: 12460/2
# Train test ratio: 6230.00
# ################################################################################
# Reading 3 segments
# Building dataset, requesting data from 0 to 3
# x here is
# [[127. 123. 118. ...  93.  93.  89.]
#  [123. 118. 112. ...  93.  89.  87.]
#  [118. 112. 108. ...  89.  87.  85.]
#  ...
#  [182. 191. 203. ... 254. 263. 280.]
#  [191. 203. 215. ... 263. 280. 288.]
#  [203. 215. 223. ... 280. 288. 301.]]
# y here is
# [[ 76.  76.  76. ...  76.  76.  76.]
#  [ 74.  74.  74. ...  74.  74.  74.]
#  [ 83.  83.  83. ...  83.  83.  83.]
#  ...
#  [307. 307. 307. ... 307. 307. 307.]
#  [311. 311. 311. ... 311. 311. 311.]
#  [321. 321. 321. ... 321. 321. 321.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 1/0
# Found 3 continuous time series
# Data shape: (2740, 12), Train/test: 1/2739
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x00000235BBBE8100>
# Epoch 0, test loss: 0.188302
# Epoch 1, test loss: 0.194869
# Epoch 2, test loss: 0.195003
# Epoch 3, test loss: 0.195748
# Epoch 4, test loss: 0.189427
# Epoch 5, test loss: 0.190550
# Epoch 6, test loss: 0.202197
# Epoch 7, test loss: 0.193321
# Epoch 8, test loss: 0.194565
# Epoch 9, test loss: 0.188960
# Pretrain data: 9407520.0
# Building dataset, requesting data from 0 to 125
# x here is
# [[116. 117. 119. ... 117. 121. 126.]
#  [117. 119. 116. ... 121. 126. 131.]
#  [119. 116. 111. ... 126. 131. 136.]
#  ...
#  [ 68.  68.  69. ...  74.  76.  79.]
#  [ 68.  69.  69. ...  76.  79.  87.]
#  [ 69.  69.  69. ...  79.  87.  95.]]
# y here is
# [[149. 149. 149. ... 149. 149. 149.]
#  [149. 149. 149. ... 149. 149. 149.]
#  [151. 151. 151. ... 151. 151. 151.]
#  ...
#  [120. 120. 120. ... 120. 120. 120.]
#  [123. 123. 123. ... 123. 123. 123.]
#  [128. 128. 128. ... 128. 128. 128.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 2889/52392
# Found 125 continuous time series
# Data shape: (55283, 12), Train/test: 55281/2
# Train test ratio: 27640.50
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 12), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 12), dtype=float32)
# line73: Shape of y: (None, 12)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  863
# Epoch 0, train loss: 0.247436
# Epoch 1, train loss: 0.243497
# Epoch 2, train loss: 0.190177
# Epoch 3, train loss: 0.195523
# Epoch 4, train loss: 0.242163
# Epoch 5, train loss: 0.176011
# Epoch 6, train loss: 0.169715
# Epoch 7, train loss: 0.232314
# Epoch 8, train loss: 0.172344
# Epoch 9, train loss: 0.244857
# Reading 11 segments
# Building dataset, requesting data from 0 to 11
# x here is
# [[214. 217. 217. ... 207. 201. 190.]
#  [217. 217. 212. ... 201. 190. 183.]
#  [217. 212. 209. ... 190. 183. 179.]
#  ...
#  [115. 107. 101. ... 128. 130. 124.]
#  [107. 101. 110. ... 130. 124. 120.]
#  [101. 110. 123. ... 124. 120. 117.]]
# y here is
# [[173. 173. 173. ... 173. 173. 173.]
#  [173. 173. 173. ... 173. 173. 173.]
#  [171. 171. 171. ... 171. 171. 171.]
#  ...
#  [129. 129. 129. ... 129. 129. 129.]
#  [139. 139. 139. ... 139. 139. 139.]
#  [157. 157. 157. ... 157. 157. 157.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 11 continuous time series
# Data shape: (2406, 12), Train/test: 1/2405
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# Reading 73 segments
# Building dataset, requesting data from 0 to 73
# x here is
# [[128. 123. 120. ... 119. 119. 118.]
#  [123. 120. 124. ... 119. 118. 117.]
#  [120. 124. 121. ... 118. 117. 117.]
#  ...
#  [323. 328. 264. ... 248. 244. 243.]
#  [328. 264. 264. ... 244. 243. 244.]
#  [264. 264. 264. ... 243. 244. 239.]]
# y here is
# [[115. 115. 115. ... 115. 115. 115.]
#  [115. 115. 115. ... 115. 115. 115.]
#  [114. 114. 114. ... 114. 114. 114.]
#  ...
#  [216. 216. 216. ... 216. 216. 216.]
#  [216. 216. 216. ... 216. 216. 216.]
#  [213. 213. 213. ... 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 1414/9217
# Found 73 continuous time series
# Data shape: (10633, 12), Train/test: 10631/2
# Train test ratio: 5315.50
# ################################################################################
# Reading 11 segments
# Building dataset, requesting data from 0 to 11
# x here is
# [[214. 217. 217. ... 207. 201. 190.]
#  [217. 217. 212. ... 201. 190. 183.]
#  [217. 212. 209. ... 190. 183. 179.]
#  ...
#  [115. 107. 101. ... 128. 130. 124.]
#  [107. 101. 110. ... 130. 124. 120.]
#  [101. 110. 123. ... 124. 120. 117.]]
# y here is
# [[173. 173. 173. ... 173. 173. 173.]
#  [173. 173. 173. ... 173. 173. 173.]
#  [171. 171. 171. ... 171. 171. 171.]
#  ...
#  [129. 129. 129. ... 129. 129. 129.]
#  [139. 139. 139. ... 139. 139. 139.]
#  [157. 157. 157. ... 157. 157. 157.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 11 continuous time series
# Data shape: (2406, 12), Train/test: 1/2405
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x00000235BD3FBF70>
# Epoch 0, test loss: 0.255990
# Epoch 1, test loss: 0.244166
# Epoch 2, test loss: 0.242794
# Epoch 3, test loss: 0.241901
# Epoch 4, test loss: 0.243237
# Epoch 5, test loss: 0.240482
# Epoch 6, test loss: 0.241301
# Epoch 7, test loss: 0.240488
# Epoch 8, test loss: 0.246396
# Epoch 9, test loss: 0.240481
# Pretrain data: 9397433.0
# Building dataset, requesting data from 0 to 171
# x here is
# [[116. 117. 119. ... 117. 121. 126.]
#  [117. 119. 116. ... 121. 126. 131.]
#  [119. 116. 111. ... 126. 131. 136.]
#  ...
#  [323. 328. 264. ... 248. 244. 243.]
#  [328. 264. 264. ... 244. 243. 244.]
#  [264. 264. 264. ... 243. 244. 239.]]
# y here is
# [[149. 149. 149. ... 149. 149. 149.]
#  [149. 149. 149. ... 149. 149. 149.]
#  [151. 151. 151. ... 151. 151. 151.]
#  ...
#  [216. 216. 216. ... 216. 216. 216.]
#  [216. 216. 216. ... 216. 216. 216.]
#  [213. 213. 213. ... 213. 213. 213.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 3574/51942
# Found 171 continuous time series
# Data shape: (55518, 12), Train/test: 55516/2
# Train test ratio: 27758.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 12), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 12), dtype=float32)
# line73: Shape of y: (None, 12)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  867
# Epoch 0, train loss: 0.205185
# Epoch 1, train loss: 0.174197
# Epoch 2, train loss: 0.375518
# Epoch 3, train loss: 0.229921
# Epoch 4, train loss: 0.196968
# Epoch 5, train loss: 0.227767
# Epoch 6, train loss: 0.173912
# Epoch 7, train loss: 0.173452
# Epoch 8, train loss: 0.199594
# Epoch 9, train loss: 0.188425
# Reading 5 segments
# Building dataset, requesting data from 0 to 5
# x here is
# [[283. 282. 281. ... 216. 208. 201.]
#  [282. 281. 277. ... 208. 201. 195.]
#  [281. 277. 267. ... 201. 195. 189.]
#  ...
#  [184. 182. 178. ... 159. 159. 156.]
#  [182. 178. 176. ... 159. 156. 154.]
#  [178. 176. 171. ... 156. 154. 152.]]
# y here is
# [[138. 138. 138. ... 138. 138. 138.]
#  [151. 151. 151. ... 151. 151. 151.]
#  [146. 146. 146. ... 146. 146. 146.]
#  ...
#  [151. 151. 151. ... 151. 151. 151.]
#  [149. 149. 149. ... 149. 149. 149.]
#  [144. 144. 144. ... 144. 144. 144.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 5 continuous time series
# Data shape: (2675, 12), Train/test: 1/2674
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# Reading 27 segments
# Building dataset, requesting data from 0 to 27
# x here is
# [[160. 158. 160. ... 192. 201. 218.]
#  [158. 160. 166. ... 201. 218. 226.]
#  [160. 166. 175. ... 218. 226. 231.]
#  ...
#  [253. 257. 258. ... 211. 202. 196.]
#  [257. 258. 258. ... 202. 196. 199.]
#  [258. 258. 249. ... 196. 199. 224.]]
# y here is
# [[246. 246. 246. ... 246. 246. 246.]
#  [259. 259. 259. ... 259. 259. 259.]
#  [269. 269. 269. ... 269. 269. 269.]
#  ...
#  [268. 268. 268. ... 268. 268. 268.]
#  [301. 301. 301. ... 301. 301. 301.]
#  [290. 290. 290. ... 290. 290. 290.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 729/9667
# Found 27 continuous time series
# Data shape: (10398, 12), Train/test: 10396/2
# Train test ratio: 5198.00
# ################################################################################
# Reading 5 segments
# Building dataset, requesting data from 0 to 5
# x here is
# [[283. 282. 281. ... 216. 208. 201.]
#  [282. 281. 277. ... 208. 201. 195.]
#  [281. 277. 267. ... 201. 195. 189.]
#  ...
#  [184. 182. 178. ... 159. 159. 156.]
#  [182. 178. 176. ... 159. 156. 154.]
#  [178. 176. 171. ... 156. 154. 152.]]
# y here is
# [[138. 138. 138. ... 138. 138. 138.]
#  [151. 151. 151. ... 151. 151. 151.]
#  [146. 146. 146. ... 146. 146. 146.]
#  ...
#  [151. 151. 151. ... 151. 151. 151.]
#  [149. 149. 149. ... 149. 149. 149.]
#  [144. 144. 144. ... 144. 144. 144.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 5 continuous time series
# Data shape: (2675, 12), Train/test: 1/2674
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x00000235BD80BA00>
# Epoch 0, test loss: 0.214779
# Epoch 1, test loss: 0.214603
# Epoch 2, test loss: 0.214443
# Epoch 3, test loss: 0.214435
# Epoch 4, test loss: 0.215103
# Epoch 5, test loss: 0.215276
# Epoch 6, test loss: 0.216371
# Epoch 7, test loss: 0.222773
# Epoch 8, test loss: 0.218811
# Epoch 9, test loss: 0.215063
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 104
#     101     all_errs.append([pid] + errs)
#     103 all_errs = np.array(all_errs)
# --> 104 np.savetxt(f"{outdir}/no_fine_tune_errors.txt", all_errs, fmt="%d %.4f %.4f")
#
# File c:\Users\baiyi\.pyenv\pyenv-win\versions\3.10.5\lib\site-packages\numpy\lib\npyio.py:1603, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1601     raise error
#    1602 elif ((not iscomplex_X) and n_fmt_chars != ncol):
# -> 1603     raise error
#    1604 else:
#    1605     format = fmt
#
# ValueError: fmt has wrong number of % formats:  %d %.4f %.4f

# %%
all_errs
# Out:
# array([[5.59000000e+02, 2.07258314e-01, 2.07258314e-01, 1.96519971e-01],
#        [5.63000000e+02, 1.88313693e-01, 1.88313693e-01, 1.96036845e-01],
#        [5.70000000e+02, 2.06858590e-01, 2.06858590e-01, 1.70068905e-01],
#        [5.88000000e+02, 1.91546440e-01, 1.91546440e-01, 1.88959986e-01],
#        [5.75000000e+02, 2.41410896e-01, 2.41410896e-01, 2.40480691e-01],
#        [5.91000000e+02, 2.20461741e-01, 2.20461741e-01, 2.15062574e-01]])

# %%
# Convert the second and third columns to floats
second_column = all_errs[:, 1].astype(float)
third_column = all_errs[:, 2].astype(float)

# Calculate the average
average_second_column = np.mean(second_column)
average_third_column = np.mean(third_column)

print("Average of the second column:", average_second_column)
print("Average of the third column:", average_third_column)
# Out:
# Average of the second column: 0.20499620338280997
# Average of the third column: 0.19652444124221802

# %% [markdown]
# # Specifically looking at the input

# %%
# Before the loop
# ATTENTION: verify the \ or / in different system window or unix
# read in all patients data
pid_2018 = [559, 563] # , 570, 588, 575, 591
# pid_2020 = [540, 552, 544, 567, 584, 596]
pid_year = {2018: pid_2018}
# pid_year = {2018: pid_2018, 2020: pid_2020}

train_data = dict()
for year in list(pid_year.keys()):
    pids = pid_year[year]
    for pid in pids:
        reader = DataReader(
            "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/{year}/train/{pid}-ws-training.xml", 6
        )
        train_data[pid] = reader.read()
# add test data of 2018 patient
use_2018_test = False
standard = False  # do not use standard
test_data_2018 = []
for pid in pid_2018:
    reader = DataReader(
        "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/test/{pid}-ws-testing.xml", 6
    )
    test_data_2018 += reader.read()

# a dumb dataset instance
train_dataset = CGMSDataSeg(
    "ohio", "C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/train/559-ws-training.xml", 6
)
sampling_horizon = 6
prediction_horizon = ph
scale = 0.01
outtype = "Same"
# train on training dataset
# k_size, nblock, nn_size, nn_layer, learning_rate, batch_size, epoch, beta
with open(os.path.join(path, "config.json")) as json_file:
    config = json.load(json_file)
argv = (
    config["k_size"],
    config["nblock"],
    config["nn_size"],
    config["nn_layer"],
    config["learning_rate"],
    config["batch_size"],
    epoch,
    config["beta"],
)
l_type = config["loss"]
# test on patients data
outdir = os.path.join(path, f"ph_{prediction_horizon}_{l_type}")
if not os.path.exists(outdir):
    os.makedirs(outdir)
all_errs = []
# Out:
# Reading 43 segments

# %%
train_dataset

# %%
# Loop

all_errs = []
for pid in pid_2018:
    print(pid)
    train_pids = set(pid_2018) - set([pid])
    local_train_data = []
    if use_2018_test:
        local_train_data += test_data_2018
    for k in train_pids:
        local_train_data += train_data[k]
    print(f"Pretrain data: {sum([sum(x) for x in local_train_data])}")

    train_dataset.data = local_train_data
    train_dataset.set_cutpoint = -1
    train_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        100,
        False,
        outtype,
        1,
        standard,
    )
    regressor(train_dataset, *argv, l_type, outdir)
    # Fine-tune and test
    target_test_dataset = CGMSDataSeg(
        "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/test/{pid}-ws-testing.xml",6
    )
    target_test_dataset.set_cutpoint = 1
    target_test_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        0.01,
        False,
        outtype,
        1,
        standard,
    )
    target_train_dataset = CGMSDataSeg(
        "ohio", f"C:/Users/baiyi/OneDrive/Desktop/BGprediction/OhioT1DM/2018/train/{pid}-ws-training.xml", 5
    )
    target_train_dataset.set_cutpoint = -1
    target_train_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        100,
        False,
        outtype,
        1,
        standard,
    )
    err, labels = test_ckpt(target_test_dataset, outdir)
    errs = [err]
    transfer_res = [labels]
    for i in range(1, 2): 
        err, labels = regressor_transfer(
            target_train_dataset,
            target_test_dataset,
            config["batch_size"],
            epoch,
            outdir,
            i,
        )
        errs.append(err)
        transfer_res.append(labels)
    transfer_res = np.concatenate(transfer_res, axis=1)
    # np.savetxt(
    #     f"{outdir}/{pid}.txt",
    #     transfer_res,
    #     fmt="%.4f %.4f %.4f %.4f",
    # )
    all_errs.append([pid] + errs)
all_errs = np.array(all_errs)

# The first error represents the output after fine-tuned, the second error represents the output from transfer learning

# np.savetxt(f"{outdir}/errors.txt", all_errs, fmt="%d %.4f %.4f")
# label pair:(groundTruth, y_pred)
# Out:
# 559
# Pretrain data: 1771039.0
# Building dataset, requesting data from 0 to 22
# x here is
# [[219. 229. 224. 221. 215. 209.]
#  [229. 224. 221. 215. 209. 203.]
#  [224. 221. 215. 209. 203. 199.]
#  ...
#  [220. 225. 232. 237. 241. 243.]
#  [225. 232. 237. 241. 243. 251.]
#  [232. 237. 241. 243. 251. 257.]]
# y here is
# [[202. 202. 202. 202. 202. 202.]
#  [192. 192. 192. 192. 192. 192.]
#  [194. 194. 194. 194. 194. 194.]
#  ...
#  [250. 250. 250. 250. 250. 250.]
#  [246. 246. 246. 246. 246. 246.]
#  [240. 240. 240. 240. 240. 240.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 693/11187
# Found 22 continuous time series
# Data shape: (11882, 6), Train/test: 11880/2
# Train test ratio: 5940.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# line73: Shape of y: (None, 6)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  185
# Epoch 0, train loss: 0.253602
# Epoch 1, train loss: 0.224297
# Epoch 2, train loss: 0.276630
# Epoch 3, train loss: 0.222666
# Epoch 4, train loss: 0.195741
# Epoch 5, train loss: 0.187573
# WARNING:tensorflow:From C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\training\saver.py:1064: remove_checkpoint (from tensorflow.python.checkpoint.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Epoch 6, train loss: 0.172023
# Epoch 7, train loss: 0.188769
# Epoch 8, train loss: 0.203892
# Epoch 9, train loss: 0.168788
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# x here is
# [[179. 183. 187. 191. 195. 199.]
#  [183. 187. 191. 195. 199. 204.]
#  [187. 191. 195. 199. 204. 209.]
#  ...
#  [188. 187. 186. 186. 186. 187.]
#  [187. 186. 186. 186. 187. 188.]
#  [186. 186. 186. 187. 188. 187.]]
# y here is
# [[215. 215. 215. 215. 215. 215.]
#  [225. 225. 225. 225. 225. 225.]
#  [233. 233. 233. 233. 233. 233.]
#  ...
#  [182. 182. 182. 182. 182. 182.]
#  [180. 180. 180. 180. 180. 180.]
#  [177. 177. 177. 177. 177. 177.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 12 continuous time series
# Data shape: (2382, 6), Train/test: 1/2381
# Train test ratio: 0.00
# ################################################################################
# Reading 44 segments
# Building dataset, requesting data from 0 to 44
# x here is
# [[101.  98. 104. 112. 120. 127.]
#  [ 98. 104. 112. 120. 127. 135.]
#  [104. 112. 120. 127. 135. 142.]
#  ...
#  [148. 148. 148. 149. 150. 152.]
#  [148. 148. 149. 150. 152. 155.]
#  [148. 149. 150. 152. 155. 156.]]
# y here is
# [[151. 151. 151. 151. 151. 151.]
#  [150. 150. 150. 150. 150. 150.]
#  [124. 124. 124. 124. 124. 124.]
#  ...
#  [168. 168. 168. 168. 168. 168.]
#  [172. 172. 172. 172. 172. 172.]
#  [176. 176. 176. 176. 176. 176.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 793/9517
# Found 44 continuous time series
# Data shape: (10312, 6), Train/test: 10310/2
# Train test ratio: 5155.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x000002A23F9740A0>
# Epoch 0, test loss: 0.212457
# Epoch 1, test loss: 0.211354
# Epoch 2, test loss: 0.213254
# Epoch 3, test loss: 0.210357
# Epoch 4, test loss: 0.208922
# Epoch 5, test loss: 0.210019
# Epoch 6, test loss: 0.207599
# Epoch 7, test loss: 0.207592
# Epoch 8, test loss: 0.215688
# Epoch 9, test loss: 0.205014
# 563
# Pretrain data: 1799610.0
# Building dataset, requesting data from 0 to 43
# x here is
# [[101.  98. 104. 112. 120. 127.]
#  [ 98. 104. 112. 120. 127. 135.]
#  [104. 112. 120. 127. 135. 142.]
#  ...
#  [148. 148. 148. 149. 150. 152.]
#  [148. 148. 149. 150. 152. 155.]
#  [148. 149. 150. 152. 155. 156.]]
# y here is
# [[151. 151. 151. 151. 151. 151.]
#  [150. 150. 150. 150. 150. 150.]
#  [124. 124. 124. 124. 124. 124.]
#  ...
#  [168. 168. 168. 168. 168. 168.]
#  [172. 172. 172. 172. 172. 172.]
#  [176. 176. 176. 176. 176. 176.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 793/9528
# Found 43 continuous time series
# Data shape: (10323, 6), Train/test: 10321/2
# Train test ratio: 5160.50
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# line73: Shape of y: (None, 6)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  161
# Epoch 0, train loss: 0.388194
# Epoch 1, train loss: 0.369691
# Epoch 2, train loss: 0.323817
# Epoch 3, train loss: 0.291473
# Epoch 4, train loss: 0.326621
# Epoch 5, train loss: 0.255222
# Epoch 6, train loss: 0.211317
# Epoch 7, train loss: 0.260180
# Epoch 8, train loss: 0.259683
# Epoch 9, train loss: 0.265130
# Reading 4 segments
# Building dataset, requesting data from 0 to 4
# x here is
# [[239. 238. 235. 233. 231. 229.]
#  [238. 235. 233. 231. 229. 227.]
#  [235. 233. 231. 229. 227. 222.]
#  ...
#  [140. 151. 154. 152. 151. 149.]
#  [151. 154. 152. 151. 149. 149.]
#  [154. 152. 151. 149. 149. 145.]]
# y here is
# [[208. 208. 208. 208. 208. 208.]
#  [205. 205. 205. 205. 205. 205.]
#  [204. 204. 204. 204. 204. 204.]
#  ...
#  [144. 144. 144. 144. 144. 144.]
#  [140. 140. 140. 140. 140. 140.]
#  [145. 145. 145. 145. 145. 145.]]
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 4 continuous time series
# Data shape: (2526, 6), Train/test: 1/2525
# Train test ratio: 0.00
# ################################################################################
# Reading 22 segments
# Building dataset, requesting data from 0 to 22
# x here is
# [[219. 229. 224. 221. 215. 209.]
#  [229. 224. 221. 215. 209. 203.]
#  [224. 221. 215. 209. 203. 199.]
#  ...
#  [220. 225. 232. 237. 241. 243.]
#  [225. 232. 237. 241. 243. 251.]
#  [232. 237. 241. 243. 251. 257.]]
# y here is
# [[202. 202. 202. 202. 202. 202.]
#  [192. 192. 192. 192. 192. 192.]
#  [194. 194. 194. 194. 194. 194.]
#  ...
#  [250. 250. 250. 250. 250. 250.]
#  [246. 246. 246. 246. 246. 246.]
#  [240. 240. 240. 240. 240. 240.]]
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 693/11187
# Found 22 continuous time series
# Data shape: (11882, 6), Train/test: 11880/2
# Train test ratio: 5940.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# ------------------in transfer----------------------
# INFO:tensorflow:Restoring parameters from ../ohio_results\ph_6_rmse\pretrain
# train_dataset
# <cgms_data_seg.CGMSDataSeg object at 0x000002A23FA73E80>
# Epoch 0, test loss: 0.193309
# Epoch 1, test loss: 0.209255
# Epoch 2, test loss: 0.191562
# Epoch 3, test loss: 0.202907
# Epoch 4, test loss: 0.194668
# Epoch 5, test loss: 0.190414
# Epoch 6, test loss: 0.203379
# Epoch 7, test loss: 0.190609
# Epoch 8, test loss: 0.190703
# Epoch 9, test loss: 0.193218

# %%
all_errs
# Out:
# array([[5.59000000e+02, 2.08077967e-01, 2.08703712e-01],
#        [5.63000000e+02, 1.90867111e-01, 1.93375528e-01]])

# %%
all_errs
# Out:
# array([[5.59000000e+02, 3.16456079e-01, 2.21673578e-01]])

# %%
target_train_dataset.data
# Out:
# [[101.0,
#   98.0,
#   104.0,
#   112.0,
#   120.0,
#   127.0,
#   135.0,
#   142.0,
#   140.0,
#   145.0,
#   148.0,
#   151.0,
#   150.0,
#   124.0,
#   130.0,
#   127.0,
#   121.0,
#   115.0,
#   111.0,
#   109.0,
#   103.0,
#   89.0,
#   76.0,
#   68.0,
#   64.0,
#   64.0,
#   66.0,
#   68.0,
#   68.0,
#   66.0,
#   66.0,
#   63.0,
#   65.0,
#   69.0,
#   71.0,
#   69.0,
#   66.0,
#   65.0,
#   64.0,
#   63.0,
#   62.0,
#   62.0,
#   60.0,
#   59.0,
#   59.0,
#   59.0,
#   67.0,
#   83.0,
#   98.0,
#   110.0,
#   154.0,
#   130.0,
#   121.0,
#   110.0,
#   106.0,
#   103.0,
#   103.0,
#   108.0,
#   116.0,
#   121.0,
#   123.0,
#   117.0,
#   109.0,
#   90.0,
#   80.0,
#   73.0,
#   65.0,
#   65.0,
#   65.0,
#   66.0,
#   66.0,
#   65.0,
#   72.0,
#   77.0,
#   79.0,
#   79.0,
#   72.0,
#   67.0,
#   67.0,
#   69.0,
#   67.0,
#   66.0,
#   68.0,
#   68.0,
#   64.0,
#   63.0,
#   65.0,
#   63.0,
#   65.0,
#   68.0,
#   68.0,
#   68.0,
#   71.0,
#   73.0,
#   71.0,
#   73.0,
#   81.0,
#   91.0,
#   90.0,
#   75.0,
#   70.0,
#   70.0,
#   68.0,
#   68.0,
#   66.0,
#   64.0,
#   63.0,
#   66.0,
#   67.0,
#   69.0,
#   70.0,
#   71.0,
#   75.0,
#   74.0,
#   76.0,
#   79.0,
#   80.0,
#   92.0,
#   147.0,
#   166.0,
#   213.0,
#   235.0,
#   240.0,
#   232.0,
#   221.0,
#   206.0,
#   194.0,
#   185.0,
#   178.0,
#   178.0,
#   176.0,
#   172.0,
#   174.0,
#   195.0,
#   193.0,
#   192.0,
#   201.0,
#   212.0,
#   226.0,
#   243.0,
#   240.0,
#   229.0,
#   223.0,
#   214.0,
#   210.0,
#   206.0,
#   196.0,
#   181.0,
#   220.0,
#   220.0,
#   210.0,
#   192.0,
#   183.0,
#   175.0,
#   162.0,
#   154.0,
#   147.0,
#   140.0,
#   135.0,
#   132.0,
#   128.0,
#   124.0,
#   121.0,
#   118.0,
#   114.0,
#   114.0,
#   116.0,
#   120.0,
#   114.0,
#   112.0,
#   110.0,
#   106.0,
#   99.0,
#   97.0,
#   97.0,
#   98.0,
#   99.0,
#   100.0,
#   103.0,
#   107.0,
#   109.0,
#   101.0,
#   97.0,
#   101.0,
#   102.0,
#   100.0,
#   100.0,
#   103.0,
#   97.0,
#   93.0,
#   91.0,
#   91.0,
#   89.0,
#   87.0,
#   86.0,
#   85.0,
#   87.0,
#   88.0,
#   88.0,
#   87.0,
#   88.0,
#   92.0,
#   92.0,
#   89.0,
#   92.0,
#   90.0,
#   89.0,
#   86.0,
#   87.0,
#   90.0,
#   92.0,
#   95.0,
#   95.0,
#   95.0,
#   96.0,
#   96.0,
#   94.0,
#   94.0,
#   101.0,
#   104.0,
#   97.0,
#   96.0,
#   96.0,
#   96.0,
#   93.0,
#   86.0,
#   86.0,
#   86.0],
#  [343.0,
#   346.0,
#   346.0,
#   344.0,
#   340.0,
#   339.0,
#   347.0,
#   340.0,
#   329.0,
#   317.0,
#   312.0,
#   314.0,
#   311.0,
#   296.0,
#   287.0,
#   282.0,
#   279.0,
#   275.0,
#   273.0,
#   273.0,
#   270.0,
#   267.0,
#   264.0,
#   266.0,
#   268.0,
#   267.0,
#   265.0,
#   262.0,
#   259.0,
#   259.0,
#   258.0,
#   258.0,
#   257.0,
#   257.0,
#   257.0,
#   254.0,
#   252.0,
#   250.0,
#   248.0,
#   247.0,
#   245.0,
#   242.0,
#   238.0,
#   240.0,
#   237.0,
#   233.0,
#   230.0,
#   226.0,
#   224.0,
#   223.0,
#   221.0,
#   222.0,
#   224.0,
#   220.0,
#   213.0,
#   210.0,
#   205.0,
#   197.0,
#   192.0,
#   186.0,
#   188.0,
#   209.0,
#   218.0,
#   218.0,
#   213.0,
#   215.0,
#   219.0,
#   225.0,
#   232.0,
#   244.0,
#   245.0,
#   242.0,
#   242.0,
#   248.0,
#   246.0,
#   237.0,
#   226.0,
#   218.0,
#   208.0,
#   201.0,
#   208.0,
#   224.0,
#   229.0,
#   239.0,
#   246.0,
#   243.0,
#   236.0,
#   236.0,
#   231.0,
#   221.0,
#   219.0,
#   212.0,
#   201.0,
#   205.0,
#   195.0,
#   189.0,
#   192.0,
#   194.0,
#   203.0,
#   192.0,
#   181.0,
#   176.0,
#   174.0,
#   185.0,
#   189.0,
#   188.0,
#   189.0,
#   194.0,
#   194.0,
#   197.0,
#   191.0,
#   187.0,
#   184.0,
#   186.0,
#   188.0,
#   192.0,
#   190.0,
#   190.0,
#   202.0,
#   209.0,
#   213.0,
#   213.0,
#   213.0,
#   207.0,
#   205.0,
#   205.0,
#   199.0,
#   195.0,
#   193.0,
#   191.0,
#   191.0,
#   187.0,
#   184.0,
#   182.0,
#   185.0,
#   189.0,
#   192.0,
#   194.0,
#   191.0,
#   195.0,
#   211.0,
#   227.0,
#   241.0,
#   259.0,
#   265.0,
#   268.0,
#   275.0,
#   280.0,
#   273.0,
#   274.0,
#   277.0,
#   272.0,
#   269.0,
#   272.0,
#   268.0,
#   267.0,
#   266.0,
#   262.0,
#   256.0,
#   253.0,
#   250.0,
#   244.0,
#   235.0,
#   231.0,
#   230.0,
#   227.0,
#   231.0,
#   229.0,
#   223.0,
#   218.0,
#   202.0,
#   187.0,
#   171.0,
#   155.0,
#   140.0,
#   126.0,
#   114.0,
#   104.0,
#   100.0,
#   97.0,
#   95.0,
#   93.0,
#   90.0,
#   63.0,
#   73.0,
#   87.0,
#   101.0,
#   113.0,
#   120.0,
#   125.0,
#   131.0,
#   129.0,
#   125.0,
#   118.0,
#   115.0,
#   115.0,
#   110.0,
#   106.0,
#   106.0,
#   105.0,
#   103.0,
#   102.0,
#   104.0,
#   104.0,
#   102.0,
#   100.0,
#   100.0,
#   100.0,
#   100.0,
#   102.0,
#   106.0,
#   107.0,
#   103.0,
#   101.0,
#   102.0,
#   102.0,
#   101.0,
#   101.0,
#   103.0,
#   105.0,
#   104.0,
#   102.0,
#   101.0,
#   98.0,
#   96.0,
#   97.0,
#   96.0,
#   97.0,
#   103.0,
#   107.0,
#   107.0,
#   107.0,
#   104.0,
#   101.0,
#   103.0,
#   104.0,
#   104.0,
#   104.0,
#   106.0,
#   109.0,
#   113.0,
#   113.0,
#   111.0,
#   108.0,
#   102.0,
#   100.0,
#   98.0,
#   98.0,
#   99.0,
#   101.0,
#   101.0,
#   100.0,
#   100.0,
#   101.0,
#   100.0,
#   97.0,
#   96.0,
#   95.0,
#   95.0,
#   96.0,
#   97.0,
#   95.0,
#   96.0,
#   99.0,
#   100.0,
#   100.0,
#   99.0,
#   100.0,
#   103.0,
#   104.0,
#   104.0,
#   104.0,
#   103.0,
#   104.0,
#   105.0,
#   106.0,
#   107.0,
#   108.0,
#   110.0,
#   111.0,
#   113.0,
#   114.0,
#   116.0,
#   117.0,
#   118.0,
#   118.0,
#   119.0,
#   118.0,
#   119.0,
#   122.0,
#   122.0,
#   123.0,
#   123.0,
#   124.0,
#   123.0,
#   124.0,
#   125.0,
#   126.0,
#   126.0,
#   127.0,
#   128.0,
#   129.0,
#   130.0,
#   132.0,
#   133.0,
#   134.0,
#   135.0,
#   136.0,
#   138.0,
#   139.0,
#   141.0,
#   150.0,
#   152.0,
#   149.0,
#   152.0,
#   167.0,
#   159.0,
#   154.0,
#   153.0,
#   151.0,
#   149.0,
#   148.0,
#   147.0,
#   147.0,
#   146.0,
#   146.0,
#   145.0,
#   143.0,
#   141.0,
#   139.0,
#   137.0,
#   135.0,
#   135.0,
#   135.0,
#   136.0,
#   136.0,
#   134.0,
#   132.0,
#   131.0,
#   130.0,
#   129.0,
#   129.0,
#   129.0,
#   128.0,
#   127.0,
#   126.0,
#   125.0,
#   125.0,
#   126.0,
#   126.0,
#   123.0,
#   120.0,
#   119.0,
#   116.0,
#   116.0,
#   116.0,
#   115.0,
#   120.0,
#   130.0,
#   128.0,
#   122.0,
#   127.0,
#   131.0,
#   143.0,
#   160.0,
#   175.0,
#   194.0,
#   208.0,
#   213.0,
#   218.0,
#   223.0,
#   230.0,
#   226.0,
#   226.0,
#   234.0,
#   237.0,
#   232.0,
#   235.0,
#   241.0,
#   241.0,
#   241.0,
#   247.0,
#   252.0,
#   253.0,
#   247.0,
#   248.0,
#   251.0,
#   253.0,
#   256.0,
#   263.0,
#   270.0,
#   295.0,
#   288.0,
#   284.0,
#   280.0,
#   278.0,
#   269.0,
#   254.0,
#   251.0,
#   247.0,
#   237.0,
#   234.0,
#   228.0,
#   223.0,
#   221.0,
#   214.0,
#   206.0,
#   194.0,
#   187.0,
#   191.0,
#   191.0,
#   180.0,
#   164.0,
#   157.0,
#   151.0,
#   148.0,
#   144.0,
#   141.0,
#   137.0,
#   126.0,
#   116.0,
#   106.0,
#   98.0,
#   92.0,
#   86.0,
#   84.0,
#   79.0,
#   74.0,
#   69.0,
#   68.0,
#   69.0,
#   70.0,
#   69.0,
#   69.0,
#   71.0,
#   72.0,
#   74.0,
#   77.0,
#   81.0,
#   83.0,
#   85.0,
#   89.0,
#   94.0,
#   102.0,
#   114.0,
#   126.0,
#   138.0,
#   150.0,
#   159.0,
#   173.0,
#   183.0,
#   191.0,
#   199.0,
#   202.0,
#   201.0,
#   201.0,
#   201.0,
#   202.0,
#   202.0,
#   203.0,
#   204.0,
#   207.0,
#   209.0,
#   209.0,
#   209.0,
#   212.0,
#   213.0,
#   213.0,
#   215.0,
#   218.0,
#   223.0,
#   230.0,
#   241.0,
#   249.0,
#   257.0,
#   262.0,
#   264.0,
#   262.0,
#   262.0,
#   261.0,
#   262.0,
#   263.0,
#   266.0,
#   268.0,
#   265.0,
#   262.0,
#   254.0,
#   246.0,
#   230.0,
#   224.0,
#   221.0,
#   215.0,
#   209.0,
#   208.0,
#   208.0,
#   219.0,
#   228.0,
#   222.0,
#   215.0,
#   212.0,
#   210.0,
#   209.0,
#   206.0,
#   202.0,
#   196.0,
#   188.0,
#   191.0,
#   188.0,
#   189.0,
#   186.0,
#   183.0,
#   183.0,
#   178.0,
#   171.0,
#   167.0,
#   166.0,
#   163.0,
#   162.0,
#   163.0,
#   164.0,
#   164.0,
#   162.0,
#   165.0,
#   165.0,
#   164.0,
#   167.0,
#   166.0,
#   158.0,
#   154.0,
#   156.0,
#   160.0,
#   158.0,
#   157.0,
#   156.0,
#   158.0,
#   159.0,
#   159.0,
#   160.0,
#   163.0,
#   168.0,
#   172.0,
#   176.0,
#   180.0,
#   184.0,
#   187.0,
#   188.0,
#   190.0,
#   192.0,
#   193.0,
#   195.0,
#   188.0,
#   186.0,
#   193.0,
#   192.0,
#   184.0,
#   177.0,
#   174.0,
#   175.0,
#   180.0,
#   182.0,
#   184.0,
#   186.0,
#   184.0,
#   183.0,
#   180.0,
#   175.0,
#   172.0,
#   170.0,
#   168.0,
#   165.0,
#   164.0,
#   163.0,
#   162.0,
#   161.0,
#   161.0,
#   160.0,
#   159.0,
#   159.0,
#   157.0,
#   156.0,
#   154.0,
#   152.0,
#   150.0,
#   149.0,
#   147.0,
#   144.0,
#   142.0,
#   139.0,
#   137.0,
#   134.0,
#   133.0,
#   132.0,
#   124.0,
#   119.0,
#   117.0,
#   118.0,
#   118.0,
#   114.0,
#   113.0,
#   110.0,
#   109.0,
#   107.0,
#   105.0,
#   103.0,
#   102.0,
#   102.0,
#   101.0,
#   101.0,
#   100.0,
#   99.0,
#   98.0,
#   97.0,
#   96.0,
#   96.0,
#   96.0,
#   95.0,
#   95.0,
#   95.0,
#   95.0,
#   95.0,
#   95.0,
#   96.0,
#   96.0,
#   95.0,
#   95.0,
#   95.0,
#   94.0,
#   94.0,
#   94.0,
#   94.0,
#   94.0,
#   95.0,
#   95.0,
#   95.0,
#   95.0,
#   95.0,
#   96.0,
#   96.0,
#   95.0,
#   95.0,
#   95.0,
#   95.0,
#   96.0,
#   95.0,
#   92.0,
#   93.0,
#   98.0,
#   89.0,
#   100.0,
#   114.0,
#   124.0,
#   137.0,
#   153.0,
#   169.0,
#   184.0,
#   191.0,
#   197.0,
#   202.0,
#   208.0,
#   212.0,
#   214.0,
#   214.0,
#   212.0,
#   207.0,
#   205.0,
#   204.0,
#   204.0,
#   202.0,
#   202.0,
#   205.0,
#   202.0,
#   196.0,
#   194.0,
#   195.0,
#   199.0,
#   201.0,
#   204.0,
#   207.0,
#   209.0,
#   210.0,
#   212.0,
#   212.0,
#   213.0,
#   219.0,
#   221.0,
#   218.0,
#   221.0,
#   237.0,
#   247.0,
#   257.0,
#   263.0,
#   265.0,
#   268.0,
#   273.0,
#   276.0,
#   272.0,
#   268.0,
#   266.0,
#   263.0,
#   260.0,
#   261.0,
#   258.0,
#   254.0,
#   249.0,
#   243.0,
#   235.0,
#   231.0,
#   229.0,
#   224.0,
#   217.0,
#   213.0,
#   214.0,
#   219.0,
#   226.0,
#   233.0,
#   250.0,
#   262.0,
#   268.0,
#   273.0,
#   283.0,
#   294.0,
#   299.0,
#   299.0,
#   298.0,
#   296.0,
#   293.0,
#   284.0,
#   264.0,
#   243.0,
#   223.0,
#   203.0,
#   178.0,
#   159.0,
#   145.0,
#   138.0,
#   135.0,
#   134.0,
#   127.0,
#   114.0,
#   104.0,
#   95.0,
#   87.0,
#   81.0,
#   77.0,
#   75.0,
#   74.0,
#   60.0,
#   61.0,
#   67.0,
#   72.0,
#   76.0,
#   79.0,
#   86.0,
#   92.0,
#   99.0,
#   106.0,
#   112.0,
#   116.0,
#   123.0,
#   131.0,
#   134.0,
#   135.0,
#   139.0,
#   140.0,
#   145.0,
#   150.0,
#   149.0,
#   147.0,
#   145.0,
#   142.0,
#   139.0,
#   137.0,
#   137.0,
#   134.0,
#   131.0,
#   130.0,
#   130.0,
#   132.0,
#   134.0,
#   136.0,
#   135.0,
#   133.0,
#   134.0,
#   134.0,
#   135.0,
#   133.0,
#   132.0,
#   135.0,
#   135.0,
#   132.0,
#   130.0,
#   130.0,
#   130.0,
#   128.0,
#   125.0,
#   122.0,
#   120.0,
#   118.0,
#   117.0,
#   115.0,
#   110.0,
#   108.0,
#   104.0,
#   103.0,
#   101.0,
#   97.0,
#   92.0,
#   86.0,
#   79.0,
#   74.0,
#   71.0,
#   66.0,
#   62.0,
#   59.0,
#   58.0,
#   54.0,
#   51.0,
#   55.0,
#   59.0,
#   66.0,
#   74.0,
#   82.0,
#   90.0,
#   93.0,
#   91.0,
#   90.0,
#   88.0,
#   87.0,
#   85.0,
#   83.0,
#   82.0,
#   86.0,
#   90.0,
#   94.0,
#   99.0,
#   102.0,
#   104.0,
#   108.0,
#   114.0,
#   118.0,
#   122.0,
#   126.0,
#   130.0,
#   134.0,
#   136.0,
#   138.0,
#   141.0,
#   141.0,
#   143.0,
#   145.0,
#   148.0,
#   149.0,
#   150.0,
#   153.0,
#   155.0,
#   156.0,
#   158.0,
#   161.0,
#   163.0,
#   166.0,
#   169.0,
#   173.0,
#   176.0,
#   179.0,
#   182.0,
#   185.0,
#   187.0,
#   189.0,
#   191.0,
#   192.0,
#   193.0,
#   194.0,
#   194.0,
#   194.0,
#   194.0,
#   193.0,
#   192.0,
#   192.0,
#   192.0,
#   191.0,
#   191.0,
#   191.0,
#   191.0,
#   191.0,
#   191.0,
#   192.0,
#   192.0,
#   191.0,
#   191.0,
#   190.0,
#   190.0,
#   189.0,
#   189.0,
#   189.0,
#   188.0,
#   187.0,
#   185.0,
#   184.0,
#   183.0,
#   182.0,
#   182.0,
#   181.0,
#   181.0,
#   180.0,
#   180.0,
#   179.0,
#   179.0,
#   179.0,
#   177.0,
#   176.0,
#   177.0,
#   177.0,
#   176.0,
#   175.0,
#   174.0,
#   173.0,
#   172.0,
#   172.0,
#   171.0,
#   170.0,
#   169.0,
#   168.0,
#   168.0,
#   167.0,
#   167.0,
#   168.0,
#   165.0,
#   158.0,
#   157.0,
#   157.0,
#   160.0,
#   163.0,
#   167.0,
#   178.0,
#   192.0,
#   205.0,
#   212.0,
#   207.0,
#   211.0,
#   218.0,
#   225.0,
#   231.0,
#   237.0,
#   244.0,
#   255.0,
#   264.0,
#   271.0,
#   275.0,
#   275.0,
#   270.0,
#   264.0,
#   259.0,
#   253.0,
#   247.0,
#   235.0,
#   232.0,
#   230.0,
#   223.0],
#  [170.0,
#   165.0,
#   160.0,
#   155.0,
#   150.0,
#   146.0,
#   143.0,
#   140.0,
#   138.0,
#   134.0,
#   131.0,
#   129.0,
#   128.0,
#   125.0,
#   120.0,
#   115.0,
#   112.0,
#   110.0,
#   110.0,
#   115.0,
#   124.0,
#   137.0,
#   150.0,
#   161.0,
#   165.0,
#   170.0,
#   180.0,
#   194.0,
#   209.0,
#   222.0,
#   232.0,
#   241.0,
#   250.0,
#   262.0,
#   274.0,
#   286.0,
#   296.0,
#   303.0,
#   311.0,
#   317.0,
#   324.0,
#   332.0,
#   335.0,
#   340.0,
#   344.0,
#   346.0,
#   342.0,
#   344.0,
#   353.0,
#   352.0,
#   348.0,
#   349.0,
#   350.0,
#   349.0,
#   352.0,
#   357.0,
#   347.0,
#   344.0,
#   343.0,
#   349.0,
#   355.0,
#   356.0,
#   357.0,
#   355.0,
#   352.0,
#   347.0,
#   342.0,
#   332.0,
#   322.0,
#   315.0,
#   308.0,
#   302.0,
#   297.0,
#   294.0,
#   291.0,
#   291.0,
#   297.0,
#   292.0,
#   289.0,
#   292.0,
#   283.0,
#   274.0,
#   263.0,
#   251.0,
#   239.0,
#   230.0,
#   216.0,
#   199.0,
#   181.0,
#   169.0,
#   155.0,
#   134.0,
#   112.0,
#   102.0,
#   96.0,
#   88.0,
#   82.0,
#   77.0,
#   73.0,
#   69.0,
#   67.0,
#   65.0,
#   70.0,
#   75.0,
#   86.0,
#   100.0,
#   109.0,
#   114.0,
#   117.0,
#   112.0,
#   108.0,
#   114.0,
#   118.0,
#   115.0,
#   115.0,
#   115.0,
#   115.0,
#   117.0,
#   110.0,
#   107.0,
#   103.0,
#   97.0,
#   96.0,
#   96.0,
#   96.0,
#   96.0,
#   95.0,
#   91.0,
#   90.0,
#   88.0,
#   80.0,
#   74.0,
#   71.0,
#   74.0,
#   78.0,
#   78.0,
#   79.0,
#   74.0,
#   74.0,
#   77.0,
#   78.0,
#   76.0,
#   74.0,
#   74.0,
#   73.0,
#   73.0,
#   73.0,
#   74.0,
#   76.0,
#   77.0,
#   77.0,
#   77.0,
#   78.0,
#   78.0,
#   79.0,
#   79.0,
#   79.0,
#   79.0,
#   81.0,
#   81.0,
#   79.0,
#   78.0,
#   80.0,
#   80.0,
#   79.0,
#   79.0,
#   80.0,
#   80.0,
#   82.0,
#   82.0,
#   83.0,
#   84.0,
#   84.0,
#   84.0,
#   84.0,
#   84.0,
#   83.0,
#   84.0,
#   84.0,
#   84.0,
#   84.0,
#   84.0,
#   84.0,
#   84.0,
#   83.0,
#   83.0,
#   84.0,
#   83.0,
#   84.0,
#   82.0,
#   80.0,
#   78.0,
#   77.0,
#   76.0,
#   77.0,
#   78.0,
#   80.0,
#   82.0,
#   82.0,
#   82.0,
#   84.0,
#   85.0,
#   84.0,
#   83.0,
#   83.0,
#   83.0,
#   84.0,
#   84.0,
#   85.0,
#   86.0,
#   87.0,
#   88.0,
#   88.0,
#   88.0,
#   90.0,
#   91.0,
#   92.0,
#   93.0,
#   95.0,
#   96.0,
#   97.0,
#   97.0,
#   96.0,
#   97.0,
#   99.0,
#   99.0,
#   98.0,
#   97.0,
#   97.0,
#   99.0,
#   97.0,
#   96.0,
#   96.0,
#   97.0,
#   98.0,
#   98.0,
#   99.0],
#  [121.0,
#   128.0,
#   136.0,
#   155.0,
#   176.0,
#   192.0,
#   208.0,
#   224.0,
#   235.0,
#   245.0,
#   255.0,
#   265.0,
#   275.0,
#   285.0,
#   293.0,
#   299.0,
#   302.0,
#   298.0,
#   284.0,
#   281.0,
#   278.0,
#   277.0,
#   283.0,
#   294.0,
#   295.0,
#   292.0,
#   289.0,
#   289.0,
#   288.0,
#   287.0,
#   281.0,
#   278.0,
#   275.0,
#   275.0,
#   276.0,
#   276.0,
#   281.0,
#   289.0,
#   294.0,
#   300.0,
#   303.0,
#   306.0,
#   299.0,
#   284.0,
#   271.0,
#   278.0,
#   273.0,
#   262.0,
#   257.0,
#   249.0,
#   238.0,
#   224.0,
#   209.0,
#   203.0,
#   178.0,
#   157.0,
#   141.0,
#   128.0,
#   114.0,
#   99.0,
#   90.0,
#   82.0,
#   81.0,
#   85.0,
#   90.0,
#   99.0,
#   104.0,
#   109.0,
#   113.0,
#   115.0,
#   114.0,
#   112.0,
#   105.0,
#   100.0,
#   103.0,
#   106.0,
#   105.0,
#   100.0,
#   95.0,
#   95.0,
#   91.0,
#   89.0,
#   84.0,
#   76.0,
#   70.0,
#   67.0],
#  [68.0,
#   70.0,
#   74.0,
#   80.0,
#   85.0,
#   91.0,
#   111.0,
#   128.0,
#   127.0,
#   110.0,
#   125.0,
#   132.0,
#   134.0,
#   135.0,
#   137.0,
#   137.0,
#   127.0,
#   116.0,
#   114.0,
#   129.0,
#   149.0,
#   167.0,
#   182.0,
#   195.0,
#   207.0,
#   218.0,
#   229.0,
#   238.0,
#   252.0,
#   254.0,
#   261.0,
#   268.0,
#   254.0,
#   261.0,
#   261.0,
#   264.0,
#   268.0,
#   269.0,
#   264.0,
#   261.0,
#   261.0,
#   267.0,
#   265.0,
#   253.0,
#   251.0,
#   261.0,
#   271.0,
#   279.0,
#   284.0,
#   288.0,
#   290.0,
#   296.0,
#   305.0,
#   315.0,
#   325.0,
#   329.0,
#   326.0,
#   311.0,
#   303.0,
#   289.0,
#   285.0,
#   290.0,
#   300.0,
#   310.0,
#   314.0,
#   315.0,
#   316.0,
#   318.0,
#   324.0,
#   320.0,
#   323.0,
#   325.0,
#   326.0,
#   330.0,
#   333.0,
#   335.0,
#   336.0,
#   336.0,
#   338.0,
#   340.0,
#   341.0,
#   337.0,
#   312.0,
#   295.0,
#   308.0,
#   306.0,
#   301.0,
#   295.0,
#   291.0,
#   283.0,
#   264.0,
#   245.0,
#   231.0,
#   218.0,
#   205.0,
#   194.0,
#   185.0,
#   177.0,
#   171.0,
#   159.0,
#   156.0,
#   155.0,
#   155.0,
#   152.0,
#   147.0,
#   145.0,
#   144.0,
#   143.0,
#   137.0,
#   132.0,
#   135.0,
#   137.0,
#   140.0,
#   145.0],
#  [188.0,
#   192.0,
#   197.0,
#   199.0,
#   201.0,
#   202.0,
#   202.0,
#   202.0,
#   202.0,
#   203.0,
#   204.0,
#   205.0,
#   206.0,
#   207.0,
#   208.0,
#   208.0,
#   207.0,
#   206.0,
#   205.0,
#   203.0,
#   202.0,
#   201.0,
#   198.0,
#   196.0,
#   191.0,
#   187.0,
#   185.0,
#   176.0,
#   171.0,
#   170.0,
#   166.0,
#   164.0,
#   158.0,
#   162.0,
#   168.0,
#   174.0,
#   181.0,
#   186.0,
#   189.0,
#   190.0,
#   194.0,
#   196.0,
#   200.0,
#   201.0,
#   202.0,
#   204.0,
#   204.0,
#   203.0,
#   202.0,
#   203.0,
#   199.0,
#   195.0,
#   195.0,
#   195.0,
#   196.0,
#   195.0,
#   194.0,
#   194.0,
#   196.0,
#   196.0,
#   198.0,
#   203.0,
#   200.0,
#   197.0,
#   196.0,
#   197.0,
#   197.0,
#   198.0,
#   197.0,
#   196.0,
#   196.0,
#   195.0,
#   196.0,
#   196.0,
#   196.0,
#   195.0,
#   193.0,
#   190.0,
#   172.0,
#   172.0,
#   183.0,
#   183.0,
#   181.0,
#   184.0,
#   193.0,
#   193.0,
#   191.0,
#   188.0,
#   187.0,
#   186.0,
#   186.0,
#   193.0,
#   196.0,
#   194.0,
#   193.0,
#   195.0,
#   190.0,
#   188.0,
#   198.0,
#   201.0,
#   201.0,
#   201.0,
#   202.0,
#   205.0,
#   210.0,
#   222.0,
#   217.0,
#   213.0,
#   218.0,
#   222.0,
#   227.0,
#   237.0,
#   240.0,
#   243.0,
#   248.0,
#   247.0,
#   247.0,
#   246.0,
#   246.0,
#   235.0,
#   248.0,
#   249.0,
#   253.0,
#   260.0,
#   259.0,
#   255.0,
#   263.0,
#   262.0,
#   256.0,
#   254.0,
#   254.0,
#   255.0,
#   272.0,
#   293.0,
#   299.0,
#   278.0,
#   279.0,
#   285.0,
#   283.0,
#   299.0,
#   317.0,
#   331.0,
#   336.0,
#   316.0,
#   294.0,
#   292.0,
#   291.0,
#   286.0,
#   277.0,
#   264.0,
#   250.0,
#   236.0,
#   222.0,
#   208.0,
#   197.0,
#   181.0,
#   183.0,
#   188.0,
#   186.0,
#   182.0,
#   153.0,
#   135.0,
#   146.0,
#   144.0,
#   132.0,
#   123.0,
#   122.0,
#   127.0,
#   129.0,
#   130.0,
#   129.0,
#   129.0,
#   131.0,
#   135.0,
#   140.0,
#   148.0,
#   151.0,
#   153.0,
#   155.0,
#   159.0,
#   164.0,
#   169.0,
#   175.0,
#   172.0,
#   169.0,
#   178.0],
#  [267.0,
#   264.0,
#   269.0,
#   270.0,
#   264.0,
#   290.0,
#   289.0,
#   295.0,
#   297.0,
#   309.0,
#   312.0,
#   326.0,
#   334.0,
#   359.0,
#   344.0,
#   343.0,
#   363.0,
#   378.0,
#   368.0,
#   348.0,
#   350.0,
#   369.0,
#   378.0,
#   391.0,
#   400.0,
#   400.0],
#  [288.0,
#   276.0,
#   269.0,
#   265.0,
#   259.0,
#   248.0,
#   239.0,
#   235.0,
#   230.0,
#   225.0,
#   229.0,
#   224.0,
#   219.0,
#   214.0,
#   210.0,
#   206.0,
#   202.0,
#   207.0,
#   206.0,
#   203.0,
#   201.0,
#   204.0,
#   208.0,
#   204.0,
#   204.0,
#   204.0,
#   204.0,
#   205.0,
#   205.0,
#   206.0,
#   206.0,
#   207.0,
#   208.0,
#   208.0,
#   214.0,
#   222.0,
#   219.0,
#   218.0,
#   217.0,
#   216.0,
#   217.0,
#   217.0,
#   216.0,
#   214.0,
#   216.0,
#   216.0,
#   216.0,
#   217.0,
#   219.0,
#   215.0,
#   210.0,
#   210.0,
#   220.0,
#   216.0,
#   219.0,
#   224.0,
#   215.0,
#   213.0,
#   207.0,
#   207.0,
#   205.0,
#   208.0,
#   214.0,
#   221.0,
#   230.0,
#   235.0,
#   229.0,
#   227.0,
#   235.0,
#   244.0],
#  [83.0,
#   78.0,
#   76.0,
#   76.0,
#   73.0,
#   75.0,
#   76.0,
#   82.0,
#   88.0,
#   91.0,
#   100.0,
#   110.0,
#   122.0,
#   135.0,
#   148.0,
#   166.0,
#   185.0,
#   197.0,
#   211.0,
#   221.0,
#   225.0,
#   223.0,
#   229.0,
#   240.0,
#   247.0,
#   252.0,
#   253.0,
#   255.0,
#   263.0,
#   269.0,
#   265.0,
#   268.0,
#   275.0,
#   282.0,
#   284.0,
#   282.0,
#   277.0,
#   274.0,
#   272.0,
#   274.0,
#   274.0,
#   272.0,
#   294.0,
#   289.0,
#   281.0,
#   278.0,
#   276.0,
#   274.0,
#   272.0,
#   267.0,
#   263.0,
#   263.0,
#   249.0,
#   235.0,
#   227.0,
#   215.0,
#   203.0,
#   186.0,
#   168.0,
#   156.0,
#   149.0,
#   142.0,
#   136.0,
#   130.0,
#   124.0,
#   118.0,
#   111.0,
#   104.0,
#   96.0,
#   83.0,
#   72.0,
#   66.0,
#   67.0,
#   67.0,
#   66.0,
#   71.0,
#   70.0,
#   67.0,
#   65.0,
#   64.0,
#   63.0,
#   61.0,
#   61.0,
#   60.0,
#   59.0,
#   59.0,
#   59.0,
#   59.0,
#   59.0,
#   60.0,
#   60.0,
#   60.0,
#   61.0,
#   62.0,
#   64.0,
#   67.0,
#   70.0,
#   72.0,
#   73.0,
#   72.0,
#   70.0,
#   69.0,
#   68.0,
#   66.0,
#   63.0,
#   62.0,
#   67.0,
#   82.0,
#   89.0,
#   91.0,
#   93.0,
#   98.0,
#   108.0,
#   122.0,
#   134.0,
#   139.0,
#   150.0,
#   165.0,
#   176.0,
#   179.0,
#   176.0,
#   174.0,
#   175.0,
#   179.0,
#   186.0,
#   192.0,
#   201.0,
#   199.0,
#   190.0,
#   188.0,
#   188.0,
#   197.0,
#   201.0,
#   208.0,
#   221.0,
#   216.0,
#   218.0,
#   219.0,
#   215.0,
#   209.0,
#   195.0,
#   181.0,
#   174.0,
#   174.0,
#   169.0,
#   160.0,
#   152.0,
#   145.0,
#   137.0,
#   135.0,
#   134.0,
#   130.0,
#   125.0,
#   117.0,
#   101.0,
#   95.0,
#   96.0,
#   104.0,
#   105.0,
#   119.0,
#   119.0,
#   125.0,
#   124.0,
#   120.0,
#   116.0,
#   113.0,
#   121.0,
#   135.0,
#   141.0,
#   144.0,
#   146.0,
#   147.0,
#   155.0,
#   173.0,
#   191.0,
#   206.0,
#   219.0,
#   220.0,
#   227.0,
#   235.0,
#   237.0,
#   231.0,
#   233.0,
#   233.0,
#   225.0,
#   220.0,
#   212.0,
#   207.0,
#   206.0,
#   201.0,
#   188.0,
#   192.0,
#   180.0,
#   174.0,
#   177.0,
#   175.0,
#   173.0,
#   164.0,
#   148.0,
#   137.0,
#   127.0,
#   120.0,
#   104.0,
#   114.0,
#   116.0,
#   119.0,
#   130.0,
#   137.0,
#   139.0,
#   138.0,
#   138.0,
#   137.0,
#   134.0,
#   132.0,
#   130.0,
#   127.0,
#   136.0,
#   152.0,
#   167.0,
#   172.0,
#   168.0,
#   166.0,
#   165.0,
#   168.0,
#   178.0,
#   187.0,
#   192.0,
#   199.0,
#   205.0,
#   211.0,
#   221.0,
#   226.0,
#   230.0,
#   231.0,
#   228.0,
#   222.0,
#   217.0,
#   216.0,
#   204.0,
#   195.0,
#   196.0,
#   202.0,
#   199.0,
#   196.0,
#   197.0,
#   202.0,
#   203.0,
#   200.0,
#   203.0,
#   213.0,
#   206.0,
#   202.0,
#   202.0,
#   210.0,
#   223.0,
#   222.0,
#   220.0,
#   215.0,
#   211.0,
#   207.0,
#   200.0,
#   194.0,
#   182.0,
#   181.0,
#   181.0,
#   184.0,
#   179.0,
#   175.0,
#   169.0,
#   163.0,
#   172.0,
#   168.0,
#   166.0,
#   175.0,
#   181.0,
#   179.0,
#   187.0,
#   197.0,
#   190.0,
#   184.0,
#   184.0,
#   180.0,
#   184.0,
#   185.0,
#   185.0,
#   193.0,
#   201.0,
#   207.0,
#   217.0,
#   221.0,
#   225.0,
#   223.0,
#   227.0,
#   230.0,
#   221.0,
#   212.0,
#   198.0,
#   189.0,
#   180.0,
#   186.0,
#   193.0,
#   196.0,
#   196.0,
#   195.0,
#   188.0,
#   187.0,
#   194.0,
#   199.0,
#   200.0,
#   198.0,
#   198.0,
#   198.0,
#   202.0,
#   207.0,
#   212.0,
#   219.0,
#   223.0,
#   224.0,
#   223.0,
#   220.0,
#   218.0,
#   215.0,
#   212.0,
#   208.0,
#   196.0,
#   186.0,
#   171.0,
#   153.0,
#   140.0,
#   131.0,
#   117.0,
#   113.0,
#   115.0,
#   115.0,
#   115.0,
#   113.0,
#   109.0,
#   104.0,
#   100.0,
#   97.0,
#   98.0,
#   101.0,
#   103.0,
#   102.0,
#   101.0,
#   100.0,
#   98.0,
#   96.0,
#   93.0,
#   92.0,
#   92.0,
#   91.0,
#   91.0,
#   90.0,
#   90.0,
#   94.0,
#   96.0,
#   95.0,
#   91.0,
#   90.0,
#   80.0,
#   73.0,
#   83.0,
#   88.0,
#   90.0,
#   91.0,
#   90.0,
#   94.0,
#   101.0,
#   96.0,
#   91.0,
#   92.0,
#   94.0,
#   97.0,
#   103.0,
#   116.0,
#   122.0,
#   119.0,
#   120.0,
#   125.0,
#   127.0,
#   129.0,
#   136.0,
#   139.0,
#   141.0,
#   142.0,
#   139.0,
#   130.0,
#   128.0,
#   131.0,
#   137.0,
#   137.0,
#   136.0,
#   135.0,
#   135.0,
#   134.0,
#   133.0,
#   125.0,
#   122.0,
#   121.0,
#   121.0,
#   128.0,
#   127.0,
#   126.0,
#   129.0,
#   130.0,
#   130.0,
#   130.0,
#   130.0,
#   131.0,
#   132.0,
#   133.0],
#  [117.0,
#   122.0,
#   129.0,
#   142.0,
#   154.0,
#   167.0,
#   194.0,
#   212.0,
#   222.0,
#   236.0,
#   241.0,
#   243.0,
#   245.0,
#   250.0,
#   249.0,
#   249.0,
#   254.0,
#   252.0,
#   247.0,
#   241.0,
#   238.0,
#   233.0,
#   229.0,
#   226.0,
#   215.0,
#   209.0,
#   206.0,
#   198.0,
#   191.0,
#   185.0,
#   181.0,
#   171.0,
#   161.0,
#   155.0,
#   145.0,
#   133.0,
#   123.0,
#   120.0,
#   120.0,
#   115.0,
#   111.0,
#   105.0,
#   98.0,
#   91.0,
#   81.0,
#   68.0,
#   73.0,
#   75.0,
#   79.0,
#   90.0,
#   108.0,
#   130.0,
#   146.0,
#   164.0,
#   180.0,
#   196.0,
#   219.0,
#   212.0,
#   218.0,
#   218.0,
#   210.0,
#   204.0,
#   200.0,
#   194.0,
#   185.0,
#   177.0,
#   168.0,
#   165.0,
#   163.0,
#   164.0,
#   162.0,
#   169.0,
#   181.0,
#   190.0,
#   201.0,
#   209.0,
#   204.0,
#   213.0,
#   224.0,
#   234.0,
#   238.0,
#   239.0,
#   236.0,
#   241.0,
#   245.0,
#   250.0,
#   257.0,
#   262.0,
#   260.0,
#   251.0,
#   246.0,
#   241.0,
#   236.0,
#   235.0,
#   239.0,
#   239.0,
#   237.0,
#   237.0,
#   234.0,
#   236.0,
#   246.0,
#   258.0,
#   269.0,
#   278.0,
#   286.0,
#   297.0,
#   302.0,
#   306.0,
#   304.0,
#   297.0,
#   285.0,
#   280.0,
#   273.0,
#   257.0,
#   244.0,
#   250.0,
#   248.0,
#   249.0,
#   251.0,
#   255.0,
#   259.0,
#   262.0,
#   263.0,
#   259.0,
#   239.0,
#   217.0,
#   202.0,
#   209.0,
#   206.0,
#   205.0,
#   201.0,
#   194.0,
#   189.0,
#   188.0,
#   190.0,
#   189.0,
#   187.0,
#   181.0,
#   175.0,
#   171.0,
#   167.0],
#  [126.0,
#   126.0,
#   122.0,
#   120.0,
#   122.0,
#   127.0,
#   134.0,
#   141.0,
#   143.0,
#   138.0,
#   137.0,
#   136.0,
#   137.0,
#   136.0,
#   136.0,
#   137.0,
#   137.0,
#   134.0,
#   131.0,
#   127.0,
#   124.0,
#   120.0,
#   115.0,
#   110.0,
#   106.0,
#   104.0,
#   103.0,
#   101.0,
#   90.0,
#   82.0,
#   85.0,
#   88.0,
#   88.0,
#   89.0,
#   91.0,
#   96.0,
#   100.0,
#   103.0,
#   106.0,
#   105.0,
#   97.0,
#   95.0,
#   92.0,
#   96.0,
#   97.0,
#   94.0,
#   88.0,
#   83.0,
#   84.0,
#   89.0,
#   97.0,
#   106.0,
#   115.0,
#   120.0,
#   118.0,
#   117.0,
#   117.0,
#   116.0,
#   116.0,
#   114.0,
#   109.0,
#   106.0,
#   104.0,
#   99.0,
#   97.0,
#   98.0,
#   98.0,
#   96.0,
#   95.0,
#   98.0,
#   101.0,
#   103.0,
#   104.0,
#   105.0,
#   105.0,
#   105.0,
#   108.0,
#   110.0,
#   113.0,
#   117.0,
#   121.0,
#   125.0,
#   130.0,
#   133.0,
#   135.0,
#   136.0,
#   138.0,
#   139.0,
#   137.0,
#   134.0,
#   131.0,
#   130.0,
#   128.0,
#   125.0,
#   122.0,
#   120.0,
#   118.0,
#   116.0,
#   116.0,
#   119.0,
#   127.0,
#   133.0,
#   133.0,
#   137.0,
#   137.0,
#   137.0,
#   132.0,
#   132.0,
#   134.0,
#   119.0,
#   107.0,
#   103.0,
#   108.0,
#   110.0,
#   111.0,
#   115.0,
#   117.0,
#   116.0,
#   115.0,
#   114.0,
#   113.0,
#   112.0,
#   110.0,
#   105.0,
#   104.0,
#   102.0,
#   100.0,
#   104.0,
#   102.0,
#   103.0,
#   104.0,
#   105.0,
#   105.0,
#   111.0,
#   116.0,
#   122.0,
#   134.0,
#   145.0,
#   156.0,
#   163.0,
#   166.0,
#   168.0],
#  [157.0,
#   153.0,
#   152.0,
#   157.0,
#   161.0,
#   158.0,
#   157.0,
#   155.0,
#   154.0,
#   152.0,
#   151.0,
#   151.0,
#   154.0,
#   155.0,
#   153.0,
#   153.0,
#   154.0,
#   152.0,
#   151.0,
#   158.0,
#   157.0,
#   153.0,
#   147.0,
#   141.0,
#   140.0,
#   140.0,
#   140.0,
#   142.0,
#   144.0,
#   151.0,
#   149.0,
#   149.0,
#   149.0,
#   146.0,
#   139.0,
#   134.0,
#   133.0,
#   129.0,
#   126.0,
#   118.0,
#   113.0,
#   116.0,
#   117.0,
#   117.0,
#   117.0,
#   119.0,
#   128.0,
#   136.0,
#   146.0,
#   155.0,
#   164.0,
#   184.0,
#   197.0,
#   206.0,
#   216.0,
#   218.0,
#   212.0,
#   205.0,
#   195.0,
#   187.0,
#   177.0,
#   169.0,
#   164.0,
#   158.0,
#   151.0,
#   149.0,
#   147.0,
#   143.0,
#   141.0,
#   139.0,
#   137.0,
#   135.0,
#   134.0,
#   135.0,
#   136.0,
#   133.0,
#   129.0,
#   127.0,
#   130.0,
#   134.0,
#   129.0,
#   128.0,
#   130.0,
#   130.0,
#   129.0,
#   126.0,
#   120.0,
#   118.0,
#   115.0,
#   108.0,
#   106.0,
#   107.0,
#   106.0,
#   105.0,
#   103.0,
#   104.0,
#   101.0,
#   97.0,
#   97.0,
#   96.0,
#   92.0,
#   91.0,
#   91.0,
#   98.0,
#   104.0,
#   103.0,
#   108.0,
#   120.0,
#   133.0,
#   142.0,
#   146.0,
#   143.0,
#   143.0,
#   143.0,
#   140.0,
#   139.0,
#   142.0,
#   152.0,
#   158.0,
#   164.0,
#   175.0,
#   188.0,
#   196.0,
#   192.0,
#   199.0,
#   198.0,
#   196.0,
#   189.0,
#   181.0,
#   178.0,
#   172.0,
#   161.0,
#   158.0,
#   132.0,
#   118.0,
#   106.0,
#   94.0,
#   89.0,
#   85.0,
#   85.0,
#   82.0,
#   81.0],
#  [60.0,
#   65.0,
#   76.0,
#   98.0,
#   106.0,
#   111.0,
#   115.0,
#   117.0,
#   123.0,
#   129.0,
#   136.0,
#   143.0,
#   152.0,
#   161.0,
#   171.0,
#   182.0,
#   193.0,
#   205.0,
#   218.0,
#   229.0,
#   240.0,
#   250.0,
#   259.0,
#   268.0,
#   277.0,
#   286.0,
#   295.0,
#   303.0,
#   310.0,
#   311.0,
#   317.0,
#   324.0,
#   330.0,
#   335.0,
#   340.0,
#   343.0,
#   346.0,
#   348.0,
#   349.0,
#   348.0,
#   348.0,
#   356.0,
#   366.0,
#   364.0,
#   358.0,
#   354.0,
#   350.0,
#   348.0,
#   346.0,
#   342.0,
#   337.0,
#   340.0,
#   364.0,
#   363.0,
#   365.0,
#   365.0,
#   364.0,
#   365.0,
#   364.0,
#   361.0,
#   353.0,
#   342.0,
#   332.0,
#   332.0,
#   329.0,
#   325.0,
#   323.0,
#   320.0,
#   316.0,
#   314.0,
#   308.0,
#   305.0,
#   305.0,
#   301.0,
#   299.0,
#   297.0,
#   293.0,
#   291.0,
#   293.0,
#   291.0,
#   282.0,
#   277.0,
#   272.0,
#   268.0,
#   265.0,
#   269.0,
#   268.0,
#   262.0,
#   254.0,
#   247.0,
#   242.0,
#   238.0,
#   234.0,
#   233.0,
#   231.0,
#   229.0,
#   223.0,
#   219.0,
#   216.0,
#   213.0,
#   211.0,
#   208.0,
#   206.0,
#   204.0,
#   201.0,
#   194.0,
#   190.0,
#   187.0,
#   173.0,
#   172.0,
#   173.0,
#   175.0,
#   176.0,
#   176.0,
#   173.0,
#   167.0,
#   159.0,
#   153.0,
#   148.0,
#   144.0,
#   143.0,
#   141.0,
#   139.0,
#   139.0,
#   139.0,
#   138.0,
#   137.0,
#   134.0,
#   131.0,
#   128.0,
#   125.0,
#   120.0,
#   115.0,
#   111.0,
#   108.0,
#   105.0,
#   103.0,
#   101.0,
#   99.0,
#   96.0,
#   94.0,
#   92.0,
#   91.0,
#   90.0,
#   88.0,
#   84.0,
#   81.0,
#   80.0,
#   81.0,
#   80.0,
#   79.0,
#   77.0,
#   76.0,
#   75.0,
#   73.0,
#   72.0,
#   70.0,
#   68.0,
#   65.0,
#   66.0,
#   67.0,
#   70.0,
#   73.0,
#   77.0,
#   82.0,
#   86.0,
#   88.0,
#   89.0,
#   87.0,
#   87.0,
#   84.0,
#   83.0,
#   85.0,
#   85.0,
#   84.0,
#   88.0,
#   96.0,
#   102.0,
#   104.0,
#   102.0,
#   106.0,
#   116.0,
#   124.0,
#   133.0,
#   141.0,
#   147.0,
#   151.0,
#   149.0,
#   143.0,
#   138.0,
#   132.0,
#   127.0,
#   121.0,
#   116.0,
#   111.0,
#   107.0,
#   103.0,
#   97.0,
#   88.0,
#   80.0,
#   78.0,
#   75.0,
#   72.0,
#   71.0,
#   71.0,
#   84.0,
#   99.0,
#   115.0,
#   111.0,
#   118.0,
#   124.0,
#   129.0,
#   135.0,
#   141.0,
#   145.0,
#   149.0,
#   146.0,
#   139.0,
#   127.0,
#   116.0,
#   109.0,
#   103.0,
#   96.0,
#   92.0,
#   87.0,
#   83.0,
#   82.0,
#   82.0,
#   80.0,
#   73.0,
#   68.0,
#   69.0,
#   72.0,
#   73.0,
#   77.0,
#   83.0,
#   92.0,
#   103.0,
#   116.0,
#   125.0,
#   129.0,
#   132.0,
#   137.0,
#   138.0,
#   134.0,
#   134.0,
#   137.0,
#   144.0,
#   162.0,
#   180.0,
#   194.0,
#   198.0,
#   195.0,
#   197.0,
#   205.0,
#   210.0,
#   212.0,
#   215.0,
#   219.0,
#   220.0,
#   220.0,
#   219.0,
#   219.0,
#   222.0,
#   224.0,
#   227.0,
#   234.0,
#   235.0,
#   235.0,
#   238.0,
#   238.0,
#   237.0,
#   239.0,
#   238.0,
#   235.0,
#   235.0,
#   233.0,
#   233.0,
#   233.0,
#   233.0,
#   234.0,
#   234.0,
#   234.0,
#   223.0,
#   208.0,
#   205.0,
#   211.0,
#   215.0,
#   219.0,
#   223.0,
#   228.0,
#   234.0,
#   240.0,
#   246.0,
#   254.0,
#   257.0,
#   255.0,
#   251.0,
#   244.0,
#   233.0,
#   220.0,
#   209.0,
#   201.0,
#   193.0,
#   187.0,
#   182.0,
#   179.0,
#   176.0,
#   174.0,
#   172.0,
#   169.0,
#   167.0,
#   168.0,
#   168.0,
#   167.0,
#   165.0,
#   163.0,
#   160.0,
#   159.0,
#   158.0,
#   154.0,
#   152.0,
#   151.0,
#   151.0,
#   151.0,
#   151.0,
#   150.0,
#   150.0,
#   150.0,
#   149.0,
#   148.0,
#   148.0,
#   148.0,
#   147.0,
#   146.0,
#   145.0,
#   144.0,
#   144.0,
#   144.0,
#   142.0,
#   141.0,
#   141.0,
#   140.0,
#   136.0,
#   136.0,
#   139.0],
#  [220.0,
#   223.0,
#   227.0,
#   230.0,
#   232.0,
#   231.0,
#   228.0,
#   224.0,
#   218.0,
#   214.0,
#   211.0,
#   211.0,
#   210.0,
#   210.0,
#   209.0,
#   210.0,
#   210.0,
#   210.0,
#   209.0,
#   208.0,
#   207.0,
#   204.0,
#   201.0,
#   196.0,
#   196.0,
#   198.0,
#   196.0,
#   192.0,
#   188.0,
#   184.0,
#   182.0,
#   177.0,
#   172.0,
#   169.0,
#   165.0,
#   155.0,
#   141.0,
#   128.0,
#   118.0,
#   114.0,
#   111.0,
#   107.0,
#   102.0,
#   95.0,
#   88.0,
#   80.0,
#   73.0,
#   72.0,
#   72.0,
#   75.0,
#   81.0,
#   86.0,
#   88.0,
#   89.0,
#   86.0,
#   81.0,
#   84.0,
#   84.0,
#   83.0,
#   85.0,
#   89.0,
#   90.0,
#   87.0,
#   92.0,
#   99.0,
#   99.0,
#   96.0,
#   101.0,
#   104.0,
#   104.0,
#   112.0,
#   123.0,
#   132.0,
#   140.0,
#   150.0,
#   159.0,
#   165.0,
#   167.0,
#   166.0,
#   163.0,
#   157.0,
#   151.0,
#   135.0,
#   129.0,
#   127.0,
#   131.0,
#   134.0,
#   136.0,
#   134.0,
#   131.0,
#   130.0,
#   128.0,
#   120.0,
#   110.0,
#   104.0,
#   100.0,
#   105.0,
#   108.0,
#   105.0,
#   102.0,
#   102.0,
#   101.0,
#   99.0,
#   97.0,
#   96.0,
#   92.0,
#   94.0,
#   97.0,
#   95.0,
#   91.0,
#   86.0,
#   88.0,
#   93.0,
#   90.0,
#   93.0,
#   101.0,
#   105.0,
#   109.0,
#   116.0,
#   126.0,
#   138.0,
#   153.0,
#   166.0,
#   161.0,
#   171.0,
#   175.0,
#   182.0,
#   187.0,
#   193.0,
#   199.0,
#   211.0,
#   214.0,
#   214.0,
#   213.0,
#   212.0,
#   209.0,
#   205.0,
#   200.0,
#   195.0,
#   188.0,
#   181.0,
#   173.0],
#  [104.0,
#   102.0,
#   97.0,
#   93.0,
#   91.0,
#   86.0,
#   82.0,
#   79.0,
#   75.0,
#   68.0,
#   69.0,
#   70.0,
#   71.0,
#   76.0,
#   81.0,
#   86.0,
#   91.0,
#   95.0,
#   98.0,
#   99.0,
#   101.0,
#   103.0,
#   103.0,
#   101.0,
#   100.0,
#   100.0,
#   102.0,
#   106.0,
#   110.0,
#   115.0,
#   118.0,
#   122.0,
#   124.0,
#   123.0,
#   137.0,
#   150.0,
#   155.0,
#   158.0,
#   165.0,
#   171.0,
#   177.0,
#   186.0,
#   194.0,
#   200.0,
#   206.0,
#   213.0,
#   220.0,
#   226.0,
#   230.0,
#   234.0,
#   237.0,
#   240.0,
#   242.0,
#   244.0,
#   245.0,
#   246.0,
#   246.0,
#   244.0,
#   244.0,
#   243.0,
#   242.0,
#   236.0,
#   238.0,
#   240.0,
#   238.0,
#   238.0,
#   237.0,
#   236.0,
#   234.0,
#   232.0,
#   231.0,
#   232.0,
#   232.0,
#   232.0,
#   230.0,
#   227.0,
#   224.0,
#   222.0,
#   220.0,
#   219.0,
#   218.0,
#   217.0,
#   218.0,
#   218.0,
#   217.0,
#   218.0,
#   218.0,
#   217.0,
#   217.0,
#   217.0,
#   220.0,
#   223.0,
#   224.0,
#   224.0,
#   225.0,
#   226.0,
#   226.0,
#   225.0,
#   225.0,
#   226.0,
#   227.0,
#   227.0,
#   228.0,
#   227.0,
#   226.0,
#   223.0,
#   222.0,
#   219.0,
#   218.0,
#   214.0,
#   210.0,
#   207.0,
#   205.0,
#   202.0,
#   202.0,
#   202.0,
#   200.0,
#   197.0,
#   195.0,
#   194.0,
#   192.0,
#   191.0,
#   189.0,
#   186.0,
#   183.0,
#   186.0,
#   205.0,
#   202.0,
#   201.0,
#   201.0,
#   204.0,
#   210.0,
#   225.0,
#   234.0,
#   229.0,
#   225.0,
#   217.0,
#   209.0,
#   207.0,
#   215.0,
#   226.0,
#   233.0,
#   233.0,
#   230.0,
#   227.0,
#   221.0,
#   212.0,
#   202.0,
#   192.0,
#   179.0,
#   167.0,
#   155.0,
#   137.0,
#   133.0,
#   128.0,
#   126.0,
#   127.0,
#   131.0,
#   130.0,
#   131.0,
#   132.0,
#   125.0,
#   117.0,
#   113.0,
#   114.0,
#   114.0,
#   114.0,
#   113.0,
#   111.0,
#   109.0,
#   109.0,
#   108.0,
#   108.0,
#   108.0,
#   108.0,
#   108.0,
#   109.0,
#   109.0,
#   106.0,
#   101.0,
#   100.0,
#   103.0,
#   104.0,
#   109.0,
#   114.0,
#   126.0,
#   139.0,
#   151.0,
#   160.0,
#   160.0,
#   162.0,
#   166.0,
#   170.0,
#   176.0,
#   190.0,
#   205.0,
#   220.0,
#   216.0,
#   222.0,
#   229.0,
#   237.0,
#   244.0,
#   251.0],
#  [259.0,
#   272.0,
#   278.0,
#   277.0,
#   284.0,
#   290.0,
#   293.0,
#   296.0,
#   300.0,
#   304.0,
#   310.0,
#   322.0,
#   328.0,
#   320.0,
#   325.0,
#   327.0,
#   326.0,
#   322.0,
#   316.0,
#   308.0,
#   300.0,
#   290.0,
#   283.0,
#   273.0,
#   266.0,
#   263.0,
#   260.0,
#   258.0,
#   258.0,
#   259.0,
#   264.0,
#   272.0,
#   277.0,
#   282.0,
#   284.0,
#   289.0,
#   290.0,
#   291.0,
#   291.0,
#   292.0,
#   294.0,
#   296.0,
#   299.0,
#   301.0,
#   301.0,
#   301.0,
#   301.0,
#   301.0,
#   300.0,
#   298.0,
#   295.0,
#   289.0,
#   285.0,
#   277.0,
#   270.0],
#  [84.0,
#   92.0,
#   100.0,
#   107.0,
#   116.0,
#   119.0,
#   124.0,
#   129.0,
#   141.0,
#   158.0,
#   165.0,
#   172.0,
#   179.0,
#   186.0,
#   194.0,
#   202.0,
#   212.0,
#   224.0,
#   227.0,
#   226.0,
#   226.0,
#   225.0,
#   230.0,
#   234.0,
#   243.0,
#   251.0,
#   267.0,
#   275.0,
#   281.0,
#   285.0,
#   286.0,
#   285.0,
#   283.0,
#   284.0,
#   280.0,
#   270.0,
#   265.0,
#   257.0,
#   247.0,
#   239.0,
#   231.0,
#   220.0,
#   209.0,
#   200.0,
#   192.0,
#   188.0,
#   184.0,
#   179.0,
#   172.0,
#   165.0,
#   151.0,
#   144.0,
#   136.0,
#   127.0,
#   122.0,
#   114.0,
#   105.0,
#   97.0,
#   89.0,
#   83.0,
#   77.0,
#   73.0,
#   73.0,
#   72.0,
#   71.0,
#   75.0,
#   77.0,
#   81.0,
#   85.0,
#   89.0],
#  [189.0,
#   197.0,
#   202.0,
#   215.0,
#   225.0,
#   230.0,
#   234.0,
#   238.0,
#   244.0,
#   250.0,
#   260.0,
#   269.0,
#   275.0,
#   280.0,
#   287.0,
#   294.0,
#   294.0,
#   296.0,
#   298.0,
#   305.0,
#   314.0,
#   315.0,
#   327.0,
#   329.0,
#   330.0,
#   329.0,
#   336.0,
#   340.0,
#   342.0,
#   350.0,
#   359.0,
#   355.0,
#   357.0,
#   363.0,
#   367.0,
#   372.0,
#   369.0,
#   366.0,
#   366.0,
#   370.0,
#   372.0,
#   367.0,
#   360.0,
#   355.0,
#   352.0,
#   347.0,
#   343.0,
#   341.0,
#   337.0,
#   327.0,
#   309.0,
#   291.0,
#   276.0,
#   267.0,
#   263.0,
#   261.0,
#   258.0,
#   251.0,
#   242.0,
#   240.0,
#   234.0,
#   223.0,
#   212.0,
#   203.0,
#   196.0,
#   189.0,
#   187.0,
#   188.0,
#   191.0,
#   194.0,
#   199.0,
#   196.0,
#   199.0,
#   198.0,
#   192.0,
#   175.0,
#   170.0,
#   170.0,
#   171.0,
#   174.0,
#   174.0,
#   172.0,
#   171.0,
#   170.0,
#   169.0,
#   168.0,
#   166.0,
#   169.0,
#   176.0,
#   169.0,
#   163.0,
#   157.0,
#   149.0,
#   143.0,
#   144.0,
#   147.0,
#   153.0,
#   160.0,
#   163.0,
#   165.0,
#   167.0,
#   158.0,
#   157.0,
#   158.0,
#   155.0,
#   154.0,
#   151.0,
#   155.0,
#   161.0,
#   156.0,
#   154.0,
#   148.0,
#   146.0,
#   147.0,
#   149.0,
#   152.0,
#   154.0,
#   148.0,
#   136.0,
#   125.0,
#   115.0,
#   105.0,
#   95.0,
#   85.0,
#   82.0,
#   79.0,
#   76.0,
#   74.0,
#   73.0,
#   74.0,
#   74.0,
#   75.0,
#   76.0,
#   77.0,
#   79.0,
#   79.0,
#   81.0,
#   82.0,
#   84.0,
#   86.0,
#   89.0,
#   92.0],
#  [184.0,
#   178.0,
#   173.0,
#   169.0,
#   166.0,
#   163.0,
#   161.0,
#   159.0,
#   157.0,
#   152.0,
#   150.0,
#   149.0,
#   148.0,
#   153.0,
#   156.0,
#   156.0,
#   149.0,
#   142.0,
#   138.0,
#   135.0,
#   135.0,
#   137.0,
#   136.0,
#   135.0,
#   133.0,
#   133.0,
#   133.0,
#   145.0,
#   148.0,
#   144.0,
#   141.0,
#   140.0,
#   140.0,
#   140.0,
#   145.0,
#   150.0,
#   161.0,
#   172.0,
#   180.0,
#   195.0,
#   205.0,
#   207.0,
#   203.0,
#   201.0,
#   202.0,
#   205.0,
#   209.0,
#   213.0,
#   215.0,
#   222.0,
#   229.0,
#   231.0,
#   231.0,
#   233.0,
#   235.0,
#   237.0,
#   235.0,
#   234.0,
#   233.0,
#   233.0,
#   230.0,
#   231.0,
#   238.0,
#   246.0,
#   254.0,
#   260.0,
#   267.0,
#   276.0,
#   282.0,
#   289.0,
#   287.0,
#   289.0,
#   300.0,
#   303.0,
#   301.0,
#   302.0,
#   301.0,
#   299.0,
#   300.0,
#   299.0,
#   294.0,
#   293.0,
#   289.0,
#   283.0,
#   280.0,
#   278.0,
#   273.0,
#   268.0,
#   265.0,
#   260.0,
#   258.0,
#   255.0,
#   246.0,
#   241.0,
#   236.0,
#   233.0,
#   227.0,
#   208.0,
#   203.0,
#   197.0,
#   192.0,
#   180.0,
#   175.0,
#   162.0,
#   151.0,
#   141.0,
#   133.0,
#   127.0,
#   123.0,
#   114.0,
#   109.0,
#   105.0,
#   100.0,
#   98.0,
#   96.0,
#   94.0,
#   93.0,
#   88.0,
#   83.0,
#   79.0,
#   73.0,
#   71.0,
#   73.0,
#   72.0,
#   75.0,
#   86.0,
#   92.0,
#   122.0,
#   134.0,
#   144.0,
#   152.0,
#   159.0,
#   167.0,
#   170.0,
#   172.0,
#   176.0,
#   178.0,
#   185.0,
#   191.0,
#   194.0,
#   199.0,
#   211.0,
#   225.0,
#   225.0,
#   228.0,
#   230.0,
#   237.0,
#   247.0,
#   253.0,
#   255.0,
#   255.0,
#   256.0,
#   263.0,
#   272.0,
#   273.0,
#   274.0,
#   272.0,
#   266.0,
#   263.0,
#   261.0,
#   257.0,
#   251.0,
#   244.0,
#   230.0,
#   215.0,
#   202.0,
#   192.0,
#   185.0,
#   173.0,
#   160.0,
#   152.0,
#   140.0,
#   131.0,
#   120.0,
#   113.0,
#   108.0,
#   105.0,
#   104.0],
#  [98.0,
#   88.0,
#   86.0,
#   82.0,
#   80.0,
#   78.0,
#   76.0,
#   74.0,
#   73.0,
#   71.0,
#   65.0,
#   61.0,
#   55.0,
#   56.0,
#   59.0,
#   63.0,
#   65.0,
#   70.0,
#   75.0,
#   81.0,
#   85.0,
#   84.0,
#   84.0,
#   85.0,
#   87.0,
#   91.0,
#   95.0,
#   97.0,
#   98.0,
#   99.0,
#   99.0,
#   100.0,
#   103.0,
#   104.0,
#   106.0,
#   108.0,
#   110.0,
#   113.0,
#   117.0,
#   119.0,
#   121.0,
#   126.0,
#   133.0,
#   139.0,
#   143.0,
#   147.0,
#   151.0,
#   158.0,
#   169.0,
#   171.0,
#   170.0,
#   171.0,
#   172.0,
#   177.0,
#   182.0,
#   186.0,
#   187.0,
#   186.0,
#   189.0,
#   191.0,
#   192.0,
#   195.0,
#   199.0,
#   203.0,
#   208.0,
#   213.0,
#   216.0,
#   217.0,
#   217.0,
#   218.0,
#   218.0,
#   218.0,
#   220.0,
#   222.0,
#   224.0,
#   223.0,
#   222.0,
#   222.0,
#   222.0,
#   221.0,
#   220.0,
#   217.0,
#   215.0,
#   213.0,
#   215.0,
#   220.0,
#   220.0,
#   217.0,
#   216.0,
#   214.0,
#   215.0,
#   214.0,
#   212.0,
#   210.0,
#   209.0,
#   207.0,
#   205.0,
#   202.0,
#   200.0,
#   202.0,
#   203.0,
#   202.0,
#   200.0,
#   200.0,
#   201.0,
#   202.0,
#   201.0,
#   203.0,
#   207.0,
#   204.0,
#   201.0,
#   199.0,
#   198.0,
#   197.0,
#   197.0,
#   196.0,
#   196.0,
#   196.0,
#   195.0,
#   195.0,
#   196.0,
#   197.0,
#   196.0,
#   195.0,
#   196.0,
#   197.0,
#   193.0,
#   193.0,
#   196.0,
#   200.0,
#   241.0,
#   252.0,
#   264.0,
#   272.0,
#   285.0,
#   290.0,
#   289.0,
#   287.0,
#   279.0,
#   271.0,
#   273.0,
#   264.0,
#   257.0,
#   250.0,
#   247.0,
#   242.0,
#   233.0,
#   225.0,
#   214.0,
#   206.0,
#   195.0,
#   184.0,
#   179.0,
#   181.0,
#   176.0,
#   170.0,
#   162.0,
#   158.0,
#   153.0,
#   145.0,
#   137.0,
#   126.0,
#   119.0,
#   120.0,
#   116.0,
#   112.0,
#   108.0,
#   103.0,
#   97.0,
#   93.0,
#   89.0,
#   89.0,
#   95.0,
#   94.0,
#   93.0,
#   91.0,
#   89.0,
#   89.0,
#   88.0,
#   88.0,
#   88.0,
#   86.0,
#   85.0,
#   84.0,
#   84.0,
#   81.0,
#   79.0,
#   75.0,
#   76.0,
#   77.0,
#   77.0,
#   80.0,
#   84.0,
#   86.0,
#   89.0,
#   99.0,
#   102.0,
#   101.0,
#   109.0,
#   123.0,
#   129.0,
#   146.0,
#   160.0,
#   171.0,
#   179.0,
#   187.0,
#   197.0,
#   209.0,
#   220.0,
#   229.0,
#   234.0,
#   235.0,
#   237.0,
#   239.0,
#   243.0,
#   248.0,
#   254.0,
#   258.0,
#   262.0,
#   267.0,
#   275.0,
#   284.0,
#   287.0,
#   292.0,
#   292.0,
#   289.0,
#   285.0,
#   286.0,
#   288.0,
#   289.0,
#   286.0,
#   283.0,
#   276.0,
#   262.0,
#   243.0,
#   229.0,
#   222.0,
#   220.0,
#   221.0,
#   223.0,
#   228.0,
#   224.0,
#   218.0,
#   208.0,
#   202.0,
#   195.0,
#   186.0,
#   181.0,
#   180.0,
#   181.0,
#   186.0,
#   190.0,
#   189.0,
#   185.0,
#   176.0,
#   167.0,
#   162.0,
#   158.0,
#   155.0,
#   152.0,
#   146.0,
#   139.0,
#   125.0,
#   118.0,
#   113.0,
#   105.0,
#   104.0,
#   102.0,
#   99.0,
#   95.0,
#   92.0,
#   90.0,
#   87.0,
#   79.0,
#   77.0,
#   74.0,
#   71.0,
#   69.0,
#   70.0,
#   70.0,
#   67.0,
#   69.0,
#   72.0,
#   74.0,
#   79.0,
#   85.0,
#   94.0,
#   104.0,
#   110.0,
#   117.0,
#   132.0,
#   143.0,
#   153.0,
#   159.0,
#   163.0,
#   166.0,
#   166.0,
#   165.0,
#   164.0,
#   163.0,
#   164.0,
#   167.0,
#   167.0,
#   165.0,
#   161.0,
#   159.0,
#   155.0,
#   152.0,
#   151.0,
#   151.0,
#   148.0,
#   142.0,
#   138.0,
#   135.0,
#   133.0,
#   132.0,
#   130.0,
#   126.0,
#   125.0,
#   126.0,
#   124.0,
#   123.0,
#   122.0,
#   121.0,
#   120.0,
#   121.0,
#   120.0,
#   115.0,
#   113.0,
#   113.0,
#   115.0,
#   117.0,
#   121.0,
#   124.0,
#   128.0,
#   131.0,
#   136.0,
#   140.0,
#   138.0,
#   135.0,
#   133.0,
#   132.0,
#   131.0,
#   132.0,
#   132.0,
#   132.0,
#   133.0,
#   134.0,
#   134.0,
#   135.0,
#   134.0,
#   133.0,
#   133.0,
#   132.0,
#   131.0,
#   130.0,
#   128.0,
#   126.0,
#   125.0,
#   124.0,
#   123.0,
#   121.0,
#   120.0,
#   119.0,
#   118.0,
#   118.0,
#   117.0,
#   117.0,
#   116.0,
#   116.0,
#   116.0,
#   117.0,
#   117.0,
#   118.0,
#   119.0,
#   120.0,
#   120.0,
#   120.0,
#   120.0,
#   120.0,
#   120.0,
#   120.0,
#   120.0,
#   120.0,
#   121.0,
#   122.0,
#   122.0,
#   123.0,
#   123.0,
#   124.0,
#   125.0,
#   125.0,
#   125.0,
#   126.0,
#   127.0,
#   128.0,
#   129.0,
#   131.0,
#   132.0,
#   132.0,
#   134.0,
#   135.0,
#   136.0,
#   136.0,
#   136.0,
#   137.0,
#   138.0,
#   139.0,
#   141.0,
#   142.0,
#   143.0,
#   143.0,
#   143.0,
#   143.0,
#   143.0,
#   144.0,
#   146.0,
#   147.0,
#   149.0,
#   151.0,
#   153.0,
#   158.0,
#   162.0,
#   164.0,
#   174.0,
#   186.0,
#   195.0,
#   207.0,
#   222.0,
#   235.0,
#   247.0,
#   257.0,
#   264.0,
#   268.0,
#   267.0,
#   267.0,
#   272.0,
#   276.0,
#   277.0,
#   279.0,
#   282.0,
#   288.0,
#   292.0,
#   294.0,
#   304.0,
#   315.0,
#   325.0,
#   337.0,
#   345.0,
#   355.0,
#   374.0,
#   390.0,
#   400.0,
#   394.0,
#   399.0,
#   400.0,
#   400.0,
#   400.0,
#   400.0,
#   400.0,
#   400.0,
#   400.0,
#   400.0,
#   400.0,
#   400.0,
#   386.0,
#   382.0,
#   378.0,
#   369.0,
#   351.0,
#   343.0,
#   332.0,
#   323.0,
#   317.0,
#   304.0,
#   287.0,
#   270.0,
#   257.0,
#   249.0,
#   239.0,
#   228.0,
#   214.0,
#   199.0,
#   185.0,
#   177.0,
#   169.0,
#   161.0,
#   154.0,
#   157.0,
#   167.0,
#   178.0,
#   186.0,
#   191.0,
#   193.0,
#   190.0,
#   186.0,
#   179.0,
#   170.0,
#   158.0,
#   145.0,
#   120.0,
#   108.0,
#   98.0,
#   91.0,
#   87.0,
#   77.0,
#   73.0,
#   73.0,
#   69.0,
#   67.0,
#   65.0,
#   63.0,
#   70.0,
#   81.0,
#   94.0,
#   111.0,
#   130.0,
#   126.0,
#   131.0,
#   126.0,
#   119.0,
#   113.0,
#   108.0,
#   103.0,
#   98.0,
#   95.0,
#   92.0,
#   88.0,
#   79.0,
#   78.0,
#   78.0,
#   80.0,
#   83.0,
#   84.0,
#   86.0,
#   90.0,
#   96.0,
#   102.0,
#   106.0,
#   107.0,
#   105.0,
#   99.0,
#   96.0,
#   96.0,
#   93.0,
#   91.0,
#   90.0,
#   89.0,
#   87.0,
#   81.0,
#   78.0,
#   79.0,
#   78.0,
#   77.0,
#   78.0,
#   83.0,
#   91.0,
#   99.0,
#   106.0,
#   108.0,
#   106.0,
#   104.0,
#   102.0,
#   99.0,
#   92.0],
#  [86.0,
#   99.0,
#   115.0,
#   129.0,
#   140.0,
#   150.0,
#   161.0,
#   172.0,
#   183.0,
#   191.0,
#   197.0,
#   202.0,
#   201.0,
#   198.0,
#   195.0,
#   192.0,
#   189.0,
#   189.0,
#   186.0,
#   182.0,
#   178.0,
#   172.0,
#   165.0,
#   159.0,
#   155.0,
#   153.0,
#   150.0,
#   145.0,
#   139.0,
#   133.0,
#   128.0,
#   122.0,
#   116.0,
#   110.0,
#   104.0,
#   99.0,
#   94.0,
#   91.0,
#   88.0,
#   84.0,
#   83.0,
#   86.0,
#   93.0,
#   98.0,
#   102.0,
#   104.0,
#   104.0,
#   102.0,
#   97.0,
#   92.0,
#   90.0,
#   88.0,
#   86.0,
#   82.0,
#   75.0,
#   75.0,
#   73.0,
#   76.0,
#   76.0,
#   74.0,
#   76.0,
#   76.0,
#   73.0,
#   71.0,
#   68.0,
#   65.0,
#   61.0,
#   58.0,
#   56.0,
#   54.0,
#   52.0,
#   50.0,
#   48.0,
#   47.0,
#   46.0,
#   45.0,
#   45.0,
#   45.0,
#   46.0,
#   47.0,
#   47.0,
#   48.0,
#   48.0,
#   47.0,
#   50.0,
#   60.0,
#   70.0,
#   60.0,
#   62.0,
#   64.0,
#   66.0,
#   69.0,
#   74.0,
#   81.0,
#   86.0,
#   91.0,
#   95.0,
#   100.0,
#   103.0,
#   107.0,
#   113.0,
#   118.0,
#   123.0,
#   128.0,
#   134.0,
#   140.0,
#   146.0,
#   151.0,
#   157.0,
#   163.0,
#   168.0,
#   174.0,
#   180.0,
#   186.0,
#   192.0,
#   198.0,
#   203.0,
#   210.0,
#   216.0,
#   222.0,
#   227.0,
#   231.0,
#   235.0,
#   238.0,
#   242.0,
#   245.0,
#   247.0,
#   247.0,
#   246.0,
#   247.0,
#   247.0,
#   246.0,
#   246.0,
#   245.0,
#   245.0,
#   244.0,
#   243.0,
#   244.0,
#   249.0,
#   359.0,
#   357.0,
#   356.0,
#   354.0,
#   350.0,
#   350.0,
#   355.0,
#   353.0,
#   347.0,
#   341.0,
#   343.0,
#   343.0,
#   342.0,
#   339.0,
#   337.0,
#   336.0,
#   333.0,
#   330.0,
#   326.0,
#   322.0,
#   318.0,
#   311.0,
#   301.0,
#   294.0,
#   288.0,
#   287.0,
#   289.0,
#   293.0,
#   293.0,
#   291.0,
#   286.0,
#   281.0,
#   276.0,
#   272.0,
#   267.0,
#   261.0,
#   254.0,
#   246.0,
#   231.0,
#   222.0,
#   224.0,
#   226.0,
#   223.0,
#   224.0,
#   216.0,
#   207.0,
#   211.0,
#   211.0,
#   222.0,
#   239.0,
#   256.0,
#   269.0,
#   278.0,
#   281.0,
#   281.0,
#   287.0,
#   303.0,
#   322.0,
#   338.0,
#   349.0,
#   344.0,
#   334.0,
#   319.0,
#   299.0,
#   279.0,
#   262.0,
#   246.0,
#   228.0,
#   211.0,
#   194.0,
#   167.0,
#   159.0,
#   148.0,
#   137.0,
#   128.0,
#   122.0,
#   115.0,
#   109.0,
#   104.0,
#   99.0,
#   91.0,
#   82.0,
#   77.0,
#   74.0,
#   72.0,
#   71.0,
#   72.0,
#   72.0,
#   66.0,
#   59.0,
#   54.0,
#   54.0,
#   60.0,
#   73.0,
#   84.0,
#   90.0,
#   86.0,
#   84.0,
#   82.0,
#   83.0,
#   85.0,
#   86.0,
#   88.0,
#   89.0,
#   88.0,
#   88.0,
#   90.0,
#   88.0,
#   94.0,
#   104.0,
#   112.0,
#   119.0,
#   125.0,
#   130.0,
#   135.0,
#   131.0,
#   129.0,
#   125.0,
#   130.0,
#   129.0,
#   133.0,
#   136.0,
#   140.0,
#   143.0,
#   143.0,
#   143.0,
#   142.0,
#   134.0,
#   122.0,
#   126.0,
#   129.0,
#   132.0,
#   136.0,
#   136.0,
#   134.0,
#   133.0,
#   138.0,
#   142.0,
#   146.0,
#   156.0,
#   165.0,
#   174.0,
#   182.0,
#   189.0,
#   192.0,
#   183.0,
#   184.0,
#   192.0,
#   202.0,
#   211.0,
#   217.0,
#   223.0,
#   227.0,
#   230.0,
#   231.0,
#   232.0,
#   233.0,
#   231.0,
#   225.0,
#   212.0,
#   201.0,
#   180.0,
#   164.0,
#   156.0,
#   149.0,
#   144.0,
#   141.0,
#   140.0,
#   144.0,
#   138.0,
#   132.0,
#   131.0,
#   135.0,
#   139.0,
#   142.0,
#   148.0,
#   151.0,
#   151.0,
#   151.0,
#   149.0,
#   147.0,
#   145.0,
#   142.0,
#   139.0,
#   139.0,
#   136.0,
#   135.0,
#   137.0,
#   138.0,
#   140.0,
#   140.0,
#   141.0,
#   140.0,
#   142.0,
#   146.0,
#   149.0,
#   153.0,
#   156.0,
#   159.0,
#   164.0,
#   167.0,
#   171.0,
#   174.0,
#   177.0,
#   180.0,
#   184.0,
#   186.0,
#   188.0,
#   190.0,
#   194.0,
#   197.0,
#   200.0,
#   202.0,
#   205.0,
#   206.0,
#   206.0,
#   207.0,
#   207.0,
#   207.0,
#   206.0,
#   204.0,
#   204.0,
#   205.0,
#   204.0,
#   203.0,
#   203.0,
#   203.0,
#   203.0,
#   202.0,
#   202.0,
#   202.0,
#   198.0,
#   198.0,
#   203.0,
#   203.0,
#   203.0,
#   203.0,
#   202.0,
#   201.0,
#   199.0,
#   198.0,
#   197.0,
#   196.0,
#   197.0,
#   196.0,
#   194.0,
#   192.0,
#   192.0,
#   191.0,
#   191.0,
#   190.0,
#   189.0,
#   187.0,
#   187.0,
#   187.0,
#   188.0,
#   189.0,
#   190.0,
#   190.0,
#   190.0,
#   190.0],
#  [224.0,
#   228.0,
#   235.0,
#   248.0,
#   261.0,
#   274.0,
#   285.0,
#   296.0,
#   302.0,
#   308.0,
#   320.0,
#   323.0,
#   323.0,
#   319.0,
#   319.0,
#   318.0,
#   315.0,
#   309.0,
#   304.0,
#   299.0,
#   295.0,
#   289.0,
#   285.0,
#   283.0,
#   276.0,
#   268.0,
#   263.0,
#   260.0,
#   256.0,
#   250.0,
#   244.0,
#   239.0,
#   233.0,
#   214.0,
#   194.0,
#   187.0,
#   174.0,
#   163.0,
#   157.0,
#   161.0,
#   168.0,
#   175.0,
#   180.0,
#   182.0,
#   180.0,
#   171.0,
#   157.0,
#   147.0,
#   139.0,
#   133.0,
#   130.0,
#   130.0,
#   129.0,
#   123.0,
#   115.0,
#   108.0,
#   101.0,
#   90.0,
#   83.0,
#   82.0,
#   81.0,
#   83.0,
#   84.0,
#   84.0,
#   81.0,
#   73.0,
#   63.0,
#   65.0,
#   69.0,
#   72.0,
#   71.0,
#   78.0,
#   90.0,
#   102.0,
#   109.0,
#   110.0,
#   119.0,
#   136.0,
#   143.0,
#   143.0,
#   144.0,
#   150.0,
#   158.0,
#   164.0,
#   167.0,
#   167.0,
#   170.0,
#   170.0,
#   167.0,
#   160.0,
#   153.0,
#   147.0,
#   148.0,
#   152.0,
#   151.0,
#   145.0,
#   139.0,
#   137.0,
#   136.0,
#   135.0,
#   135.0,
#   140.0,
#   143.0,
#   141.0,
#   138.0,
#   140.0,
#   146.0,
#   149.0,
#   152.0,
#   155.0,
#   159.0,
#   164.0,
#   171.0,
#   183.0,
#   187.0,
#   194.0,
#   183.0,
#   166.0,
#   178.0,
#   188.0,
#   199.0,
#   204.0,
#   194.0,
#   189.0,
#   182.0,
#   180.0,
#   188.0,
#   200.0,
#   208.0,
#   212.0,
#   212.0,
#   212.0,
#   212.0,
#   210.0,
#   209.0,
#   208.0,
#   205.0,
#   201.0,
#   198.0,
#   202.0,
#   199.0],
#  [198.0,
#   200.0,
#   202.0,
#   206.0,
#   215.0,
#   219.0,
#   220.0,
#   220.0,
#   220.0,
#   216.0,
#   215.0,
#   214.0,
#   213.0,
#   210.0,
#   208.0,
#   206.0,
#   205.0,
#   204.0,
#   204.0,
#   203.0,
#   179.0,
#   179.0,
#   186.0,
#   187.0,
#   189.0,
#   191.0,
#   193.0,
#   195.0,
#   197.0,
#   197.0,
#   193.0,
#   192.0,
#   197.0,
#   200.0,
#   203.0,
#   203.0,
#   204.0,
#   207.0,
#   208.0,
#   211.0,
#   197.0,
#   190.0,
#   195.0,
#   197.0,
#   199.0,
#   199.0,
#   197.0,
#   199.0,
#   199.0,
#   198.0,
#   212.0,
#   214.0,
#   215.0,
#   214.0,
#   214.0,
#   214.0,
#   214.0,
#   216.0,
#   216.0,
#   217.0,
#   217.0,
#   218.0,
#   215.0,
#   214.0,
#   212.0,
#   210.0,
#   205.0,
#   209.0,
#   215.0,
#   216.0,
#   219.0,
#   219.0,
#   217.0,
#   217.0,
#   217.0,
#   207.0,
#   195.0,
#   209.0,
#   216.0,
#   222.0,
#   225.0,
#   229.0,
#   231.0,
#   229.0,
#   226.0,
#   230.0,
#   234.0,
#   237.0,
#   238.0,
#   239.0,
#   240.0,
#   240.0,
#   240.0,
#   241.0,
#   243.0,
#   243.0,
#   242.0,
#   245.0,
#   246.0,
#   252.0,
#   256.0,
#   257.0,
#   257.0,
#   255.0,
#   251.0,
#   254.0,
#   253.0,
#   249.0,
#   251.0,
#   252.0,
#   245.0,
#   242.0,
#   242.0,
#   236.0,
#   218.0,
#   228.0,
#   239.0,
#   249.0,
#   236.0,
#   239.0,
#   240.0,
#   239.0,
#   235.0,
#   227.0,
#   217.0,
#   216.0,
#   221.0],
#  [384.0,
#   385.0,
#   395.0,
#   385.0,
#   370.0,
#   356.0,
#   344.0,
#   323.0,
#   323.0,
#   331.0,
#   329.0,
#   326.0,
#   323.0,
#   323.0,
#   331.0,
#   322.0,
#   302.0,
#   282.0,
#   266.0,
#   255.0,
#   247.0,
#   241.0,
#   235.0,
#   231.0,
#   228.0,
#   224.0,
#   226.0,
#   221.0,
#   217.0,
#   217.0,
#   219.0,
#   218.0,
#   215.0,
#   213.0,
#   202.0,
#   193.0,
#   193.0,
#   194.0,
#   197.0,
#   199.0,
#   195.0,
#   193.0,
#   212.0,
#   238.0,
#   272.0,
#   277.0,
#   275.0,
#   270.0,
#   262.0,
#   252.0,
#   239.0,
#   226.0,
#   217.0,
#   210.0,
#   207.0,
#   193.0,
#   164.0,
#   156.0,
#   123.0,
#   98.0,
#   83.0,
#   73.0,
#   67.0,
#   65.0,
#   64.0,
#   65.0,
#   68.0,
#   72.0,
#   73.0,
#   74.0],
#  [87.0,
#   93.0,
#   100.0,
#   111.0,
#   133.0,
#   160.0,
#   194.0,
#   212.0,
#   226.0,
#   233.0,
#   239.0,
#   242.0,
#   245.0,
#   245.0,
#   243.0,
#   248.0,
#   248.0,
#   232.0,
#   212.0,
#   199.0,
#   191.0,
#   183.0,
#   176.0,
#   176.0,
#   184.0,
#   187.0,
#   186.0,
#   184.0,
#   185.0,
#   182.0,
#   130.0,
#   122.0,
#   112.0,
#   107.0,
#   103.0,
#   109.0,
#   122.0,
#   151.0,
#   143.0,
#   148.0,
#   148.0,
#   145.0,
#   142.0,
#   137.0,
#   132.0,
#   127.0,
#   116.0,
#   111.0,
#   105.0,
#   101.0,
#   98.0,
#   96.0,
#   94.0,
#   91.0,
#   88.0,
#   86.0,
#   84.0,
#   82.0,
#   77.0,
#   73.0,
#   72.0,
#   70.0,
#   68.0,
#   67.0,
#   67.0,
#   66.0,
#   66.0,
#   64.0,
#   61.0,
#   64.0,
#   73.0,
#   75.0,
#   74.0,
#   72.0,
#   75.0,
#   74.0,
#   73.0,
#   75.0,
#   77.0,
#   79.0,
#   83.0,
#   90.0,
#   98.0,
#   104.0,
#   113.0,
#   116.0,
#   115.0,
#   116.0,
#   121.0,
#   126.0,
#   132.0,
#   141.0,
#   148.0,
#   152.0,
#   160.0,
#   167.0,
#   169.0,
#   163.0,
#   158.0,
#   156.0,
#   153.0,
#   143.0,
#   137.0,
#   136.0,
#   161.0,
#   180.0,
#   173.0,
#   176.0,
#   176.0,
#   175.0,
#   174.0,
#   174.0,
#   174.0,
#   174.0,
#   174.0,
#   169.0,
#   163.0,
#   156.0,
#   147.0,
#   148.0,
#   172.0,
#   187.0,
#   189.0,
#   191.0,
#   195.0,
#   203.0,
#   190.0,
#   199.0,
#   198.0,
#   198.0,
#   214.0,
#   233.0,
#   253.0,
#   280.0,
#   295.0,
#   304.0,
#   295.0,
#   293.0,
#   293.0,
#   294.0,
#   294.0,
#   297.0,
#   305.0,
#   312.0,
#   317.0,
#   315.0,
#   313.0,
#   305.0,
#   299.0,
#   285.0,
#   294.0,
#   297.0,
#   298.0,
#   297.0,
#   297.0,
#   295.0,
#   297.0,
#   291.0,
#   284.0,
#   288.0,
#   296.0,
#   295.0,
#   289.0,
#   278.0,
#   265.0,
#   252.0,
#   243.0,
#   235.0,
#   228.0,
#   215.0,
#   210.0,
#   203.0,
#   190.0,
#   195.0,
#   199.0,
#   192.0,
#   185.0,
#   183.0,
#   177.0,
#   171.0,
#   167.0,
#   170.0,
#   162.0,
#   150.0,
#   148.0,
#   138.0,
#   136.0,
#   140.0,
#   138.0,
#   133.0,
#   130.0,
#   132.0,
#   129.0,
#   128.0,
#   126.0,
#   127.0,
#   131.0,
#   134.0,
#   138.0,
#   139.0,
#   145.0,
#   160.0,
#   165.0,
#   158.0,
#   150.0,
#   156.0,
#   158.0,
#   158.0,
#   155.0,
#   153.0,
#   151.0,
#   147.0,
#   144.0,
#   143.0,
#   142.0,
#   144.0,
#   144.0,
#   144.0,
#   144.0,
#   138.0,
#   131.0,
#   124.0,
#   123.0,
#   122.0,
#   121.0,
#   118.0,
#   112.0,
#   110.0,
#   116.0,
#   111.0,
#   98.0,
#   87.0,
#   77.0,
#   70.0,
#   64.0,
#   60.0,
#   57.0,
#   57.0,
#   56.0,
#   56.0,
#   57.0,
#   57.0,
#   57.0,
#   58.0,
#   59.0,
#   60.0,
#   65.0,
#   70.0,
#   77.0,
#   88.0,
#   101.0,
#   110.0,
#   104.0,
#   106.0,
#   108.0,
#   110.0,
#   124.0,
#   143.0,
#   149.0,
#   156.0,
#   162.0,
# ...
#   146.0,
#   146.0,
#   143.0,
#   140.0,
#   139.0,
#   138.0,
#   137.0,
#   139.0,
#   141.0,
#   140.0,
#   139.0,
#   139.0,
#   138.0,
#   137.0],
#  [193.0,
#   198.0,
#   206.0,
#   215.0,
#   225.0,
#   234.0,
#   244.0,
#   252.0,
#   257.0,
#   255.0,
#   256.0,
#   265.0,
#   269.0,
#   270.0,
#   276.0,
#   280.0,
#   285.0,
#   288.0,
#   282.0,
#   273.0,
#   262.0,
#   254.0,
#   248.0,
#   238.0,
#   229.0,
#   222.0,
#   217.0,
#   210.0,
#   201.0,
#   186.0,
#   172.0,
#   162.0,
#   155.0,
#   151.0,
#   146.0,
#   138.0,
#   132.0,
#   128.0,
#   124.0,
#   118.0,
#   108.0,
#   106.0,
#   103.0,
#   98.0,
#   93.0,
#   90.0,
#   89.0,
#   88.0,
#   88.0,
#   89.0,
#   87.0,
#   87.0,
#   84.0,
#   79.0,
#   78.0,
#   79.0,
#   83.0,
#   94.0,
#   110.0,
#   113.0,
#   130.0,
#   147.0,
#   167.0,
#   187.0,
#   207.0,
#   224.0,
#   238.0,
#   254.0,
#   270.0,
#   300.0,
#   315.0,
#   311.0,
#   329.0,
#   337.0,
#   345.0,
#   345.0,
#   341.0,
#   348.0,
#   355.0,
#   359.0,
#   362.0,
#   363.0,
#   364.0,
#   363.0,
#   362.0,
#   362.0,
#   358.0,
#   342.0,
#   338.0,
#   332.0,
#   330.0,
#   328.0,
#   320.0,
#   324.0,
#   328.0,
#   335.0,
#   343.0,
#   350.0,
#   355.0,
#   364.0,
#   372.0,
#   373.0,
#   370.0,
#   376.0,
#   380.0,
#   380.0,
#   375.0,
#   362.0,
#   351.0,
#   335.0,
#   320.0,
#   312.0,
#   308.0,
#   300.0,
#   287.0,
#   276.0,
#   268.0,
#   263.0,
#   257.0,
#   247.0,
#   235.0,
#   223.0,
#   216.0,
#   209.0,
#   203.0,
#   197.0,
#   186.0,
#   176.0,
#   168.0,
#   163.0,
#   154.0,
#   153.0,
#   157.0,
#   162.0,
#   168.0,
#   176.0,
#   172.0,
#   172.0,
#   191.0,
#   188.0,
#   187.0,
#   190.0,
#   196.0,
#   196.0,
#   199.0,
#   204.0,
#   208.0,
#   212.0,
#   217.0,
#   223.0,
#   228.0,
#   234.0,
#   240.0,
#   243.0,
#   248.0,
#   253.0,
#   258.0,
#   267.0,
#   277.0,
#   281.0,
#   282.0,
#   284.0,
#   287.0,
#   292.0,
#   289.0,
#   289.0,
#   288.0,
#   287.0,
#   286.0,
#   286.0,
#   285.0,
#   283.0,
#   281.0,
#   279.0,
#   279.0,
#   281.0,
#   280.0,
#   278.0,
#   276.0,
#   276.0,
#   279.0,
#   286.0,
#   287.0,
#   287.0,
#   288.0,
#   289.0,
#   290.0,
#   293.0,
#   296.0,
#   300.0,
#   303.0,
#   306.0,
#   308.0,
#   310.0,
#   313.0,
#   315.0,
#   315.0,
#   315.0,
#   315.0,
#   316.0,
#   316.0,
#   314.0,
#   321.0,
#   319.0,
#   315.0,
#   312.0,
#   301.0,
#   268.0,
#   268.0,
#   271.0,
#   277.0,
#   282.0,
#   281.0,
#   274.0,
#   268.0,
#   259.0,
#   247.0,
#   235.0,
#   222.0,
#   209.0,
#   195.0,
#   182.0,
#   170.0,
#   160.0,
#   150.0,
#   142.0,
#   134.0,
#   127.0,
#   119.0,
#   113.0,
#   109.0,
#   105.0,
#   101.0,
#   97.0,
#   95.0,
#   92.0,
#   89.0,
#   87.0,
#   85.0,
#   83.0,
#   81.0,
#   80.0,
#   78.0,
#   77.0,
#   75.0,
#   73.0,
#   71.0,
#   70.0,
#   69.0,
#   68.0,
#   67.0,
#   66.0,
#   65.0,
#   64.0,
#   64.0,
#   63.0,
#   63.0,
#   63.0,
#   66.0,
#   70.0,
#   74.0,
#   62.0,
#   67.0,
#   73.0,
#   78.0,
#   86.0,
#   95.0,
#   103.0,
#   110.0,
#   117.0,
#   121.0,
#   125.0,
#   129.0,
#   133.0,
#   137.0,
#   141.0,
#   147.0,
#   152.0,
#   157.0,
#   162.0,
#   166.0,
#   168.0,
#   171.0,
#   175.0,
#   183.0,
#   186.0,
#   193.0,
#   198.0,
#   212.0,
#   220.0,
#   230.0,
#   240.0,
#   251.0,
#   268.0,
#   281.0,
#   289.0,
#   295.0,
#   292.0,
#   293.0,
#   298.0,
#   301.0,
#   302.0,
#   303.0,
#   305.0,
#   305.0,
#   309.0,
#   307.0,
#   303.0,
#   303.0,
#   302.0,
#   296.0,
#   290.0,
#   281.0,
#   270.0,
#   261.0,
#   250.0,
#   239.0,
#   230.0,
#   222.0,
#   213.0,
#   206.0,
#   198.0,
#   192.0,
#   185.0,
#   178.0,
#   170.0,
#   169.0,
#   168.0,
#   163.0,
#   161.0,
#   159.0,
#   157.0,
#   156.0,
#   155.0,
#   153.0,
#   150.0,
#   147.0,
#   145.0,
#   142.0,
#   139.0,
#   137.0,
#   135.0,
#   130.0,
#   127.0,
#   128.0,
#   121.0,
#   118.0,
#   115.0,
#   112.0,
#   108.0,
#   105.0,
#   103.0,
#   101.0,
#   99.0,
#   104.0,
#   108.0,
#   113.0,
#   117.0,
#   119.0,
#   122.0,
#   122.0,
#   121.0,
#   121.0,
#   118.0,
#   115.0,
#   113.0,
#   110.0,
#   106.0,
#   100.0,
#   100.0,
#   97.0,
#   93.0,
#   87.0,
#   82.0,
#   81.0,
#   78.0,
#   75.0,
#   73.0,
#   70.0,
#   68.0,
#   69.0,
#   68.0,
#   68.0,
#   66.0,
#   64.0,
#   63.0,
#   63.0,
#   67.0,
#   80.0,
#   96.0,
#   111.0,
#   123.0,
#   139.0,
#   150.0,
#   163.0,
#   171.0,
#   179.0,
#   191.0,
#   206.0,
#   218.0,
#   235.0,
#   252.0,
#   262.0,
#   271.0,
#   282.0,
#   292.0,
#   300.0,
#   305.0,
#   312.0,
#   313.0,
#   315.0,
#   320.0,
#   319.0,
#   318.0,
#   311.0,
#   301.0,
#   292.0,
#   280.0,
#   267.0,
#   271.0,
#   266.0,
#   260.0,
#   249.0,
#   239.0,
#   229.0,
#   220.0,
#   210.0,
#   201.0,
#   192.0],
#  [228.0,
#   234.0,
#   239.0,
#   241.0,
#   242.0,
#   241.0,
#   236.0,
#   229.0,
#   223.0,
#   215.0,
#   204.0,
#   194.0,
#   183.0,
#   166.0,
#   152.0,
#   142.0,
#   132.0,
#   120.0,
#   110.0,
#   107.0,
#   103.0,
#   99.0,
#   98.0,
#   97.0,
#   95.0,
#   94.0,
#   91.0,
#   90.0,
#   89.0,
#   88.0,
#   89.0,
#   89.0,
#   87.0,
#   87.0,
#   87.0,
#   88.0,
#   89.0,
#   90.0,
#   90.0,
#   92.0,
#   94.0,
#   96.0,
#   98.0,
#   101.0,
#   103.0,
#   105.0,
#   107.0,
#   109.0,
#   110.0,
#   113.0,
#   114.0,
#   114.0,
#   114.0,
#   115.0,
#   117.0,
#   119.0,
#   122.0,
#   125.0,
#   128.0,
#   130.0,
#   134.0,
#   136.0,
#   138.0,
#   141.0,
#   143.0,
#   145.0,
#   146.0,
#   147.0,
#   147.0,
#   148.0,
#   149.0,
#   147.0,
#   145.0,
#   143.0,
#   142.0,
#   140.0,
#   139.0,
#   140.0,
#   142.0,
#   143.0,
#   144.0,
#   145.0,
#   146.0,
#   147.0,
#   147.0,
#   147.0,
#   148.0,
#   147.0,
#   147.0,
#   147.0,
#   146.0,
#   145.0,
#   144.0,
#   143.0,
#   142.0,
#   140.0,
#   138.0,
#   137.0,
#   135.0,
#   133.0,
#   132.0,
#   130.0,
#   129.0,
#   128.0,
#   127.0,
#   125.0,
#   124.0,
#   123.0,
#   122.0,
#   122.0,
#   122.0,
#   122.0,
#   123.0,
#   121.0,
#   121.0,
#   122.0,
#   123.0,
#   130.0,
#   141.0,
#   151.0,
#   164.0,
#   183.0,
#   168.0,
#   179.0,
#   189.0,
#   185.0,
#   186.0,
#   187.0,
#   189.0,
#   190.0,
#   191.0,
#   191.0,
#   188.0,
#   185.0,
#   182.0,
#   177.0,
#   173.0,
#   169.0,
#   166.0,
#   164.0,
#   164.0,
#   160.0,
#   157.0,
#   157.0,
#   156.0,
#   156.0,
#   150.0,
#   151.0,
#   155.0,
#   162.0,
#   170.0,
#   174.0,
#   179.0,
#   186.0,
#   194.0,
#   200.0,
#   204.0,
#   209.0,
#   214.0,
#   219.0,
#   223.0,
#   227.0,
#   223.0,
#   220.0,
#   212.0,
#   203.0,
#   187.0,
#   177.0,
#   169.0,
#   161.0,
#   153.0,
#   146.0,
#   142.0,
#   135.0,
#   130.0,
#   124.0,
#   117.0,
#   112.0,
#   107.0,
#   98.0,
#   92.0,
#   87.0,
#   79.0,
#   72.0,
#   65.0,
#   59.0,
#   55.0,
#   51.0,
#   53.0,
#   58.0,
#   62.0,
#   75.0,
#   89.0,
#   103.0,
#   117.0,
#   130.0,
#   141.0,
#   150.0,
#   157.0,
#   162.0,
#   167.0,
#   169.0,
#   164.0,
#   162.0,
#   157.0,
#   151.0,
#   145.0,
#   142.0,
#   142.0,
#   145.0,
#   146.0,
#   148.0,
#   150.0,
#   150.0,
#   151.0,
#   151.0,
#   154.0,
#   173.0,
#   171.0,
#   173.0,
#   174.0,
#   177.0,
#   177.0,
#   181.0,
#   184.0,
#   189.0,
#   194.0,
#   200.0,
#   207.0,
#   210.0,
#   214.0,
#   222.0,
#   228.0,
#   235.0,
#   239.0,
#   248.0,
#   254.0,
#   254.0,
#   252.0,
#   249.0,
#   244.0,
#   244.0,
#   246.0,
#   244.0,
#   243.0,
#   242.0,
#   243.0,
#   246.0,
#   244.0,
#   243.0,
#   240.0,
#   236.0,
#   229.0,
#   227.0,
#   220.0,
#   216.0,
#   205.0,
#   196.0,
#   183.0,
#   182.0,
#   180.0,
#   183.0,
#   187.0,
#   191.0,
#   195.0,
#   197.0,
#   191.0,
#   182.0,
#   177.0,
#   173.0,
#   169.0,
#   162.0,
#   151.0,
#   147.0,
#   144.0,
#   140.0,
#   139.0,
#   137.0,
#   135.0,
#   132.0,
#   130.0,
#   130.0,
#   130.0,
#   129.0,
#   127.0,
#   127.0,
#   125.0,
#   123.0,
#   121.0,
#   122.0,
#   122.0,
#   120.0,
#   120.0,
#   120.0,
#   119.0,
#   119.0,
#   116.0,
#   109.0,
#   106.0,
#   105.0,
#   103.0,
#   97.0,
#   94.0,
#   95.0,
#   96.0,
#   98.0,
#   99.0,
#   102.0,
#   104.0,
#   105.0,
#   106.0,
#   105.0,
#   104.0,
#   104.0,
#   106.0,
#   106.0,
#   105.0,
#   107.0,
#   107.0,
#   106.0,
#   104.0,
#   102.0,
#   102.0,
#   101.0,
#   100.0,
#   98.0,
#   97.0,
#   96.0,
#   94.0,
#   92.0,
#   91.0,
#   89.0,
#   88.0,
#   87.0,
#   85.0,
#   84.0,
#   83.0,
#   82.0,
#   80.0,
#   78.0,
#   75.0,
#   72.0,
#   70.0,
#   68.0,
#   66.0,
#   64.0,
#   62.0,
#   60.0,
#   59.0,
#   57.0,
#   55.0,
#   54.0,
#   52.0,
#   51.0,
#   50.0,
#   48.0,
#   48.0,
#   47.0,
#   47.0],
#  [50.0,
#   51.0,
#   54.0,
#   60.0,
#   67.0,
#   74.0,
#   80.0,
#   86.0,
#   90.0,
#   92.0,
#   92.0,
#   92.0,
#   92.0,
#   93.0,
#   94.0,
#   96.0,
#   98.0,
#   101.0,
#   105.0,
#   109.0,
#   114.0,
#   118.0,
#   121.0,
#   123.0,
#   125.0,
#   128.0,
#   130.0,
#   132.0,
#   133.0,
#   134.0,
#   134.0,
#   134.0,
#   136.0,
#   136.0,
#   136.0,
#   138.0,
#   140.0,
#   146.0,
#   152.0,
#   180.0,
#   190.0,
#   203.0,
#   218.0,
#   234.0,
#   247.0,
#   262.0,
#   279.0,
#   294.0,
#   308.0,
#   321.0,
#   316.0,
#   323.0,
#   327.0,
#   335.0,
#   343.0,
#   356.0,
#   359.0,
#   357.0,
#   354.0,
#   351.0,
#   345.0,
#   344.0,
#   344.0,
#   345.0,
#   337.0,
#   332.0,
#   331.0,
#   326.0,
#   320.0,
#   313.0,
#   302.0,
#   295.0,
#   286.0,
#   279.0,
#   272.0,
#   266.0,
#   257.0,
#   255.0,
#   253.0,
#   250.0,
#   238.0,
#   223.0,
#   213.0,
#   200.0,
#   187.0,
#   175.0,
#   161.0,
#   145.0,
#   131.0,
#   118.0,
#   109.0,
#   101.0,
#   91.0,
#   84.0,
#   79.0,
#   71.0,
#   67.0,
#   65.0,
#   63.0,
#   62.0,
#   60.0,
#   60.0,
#   68.0,
#   83.0,
#   93.0,
#   101.0,
#   108.0,
#   116.0,
#   122.0,
#   128.0,
#   131.0,
#   130.0,
#   126.0,
#   120.0,
#   112.0,
#   105.0,
#   98.0,
#   94.0,
#   93.0,
#   95.0,
#   99.0,
#   105.0,
#   113.0,
#   119.0,
#   123.0,
#   134.0,
#   143.0],
#  [259.0,
#   261.0,
#   263.0,
#   257.0,
#   251.0,
#   246.0,
#   244.0,
#   247.0,
#   250.0,
#   251.0,
#   251.0,
#   257.0,
#   256.0,
#   252.0,
#   252.0,
#   256.0,
#   256.0,
#   259.0,
#   261.0,
#   262.0,
#   258.0,
#   260.0,
#   256.0,
#   243.0,
#   234.0,
#   228.0,
#   225.0,
#   231.0,
#   234.0,
#   236.0,
#   240.0,
#   244.0,
#   238.0,
#   239.0,
#   231.0,
#   226.0,
#   226.0,
#   229.0,
#   238.0,
#   241.0,
#   237.0,
#   233.0,
#   236.0,
#   235.0,
#   235.0,
#   235.0,
#   246.0,
#   252.0,
#   252.0,
#   251.0,
#   247.0,
#   249.0,
#   255.0,
#   265.0,
#   263.0,
#   259.0,
#   260.0,
#   261.0,
#   274.0,
#   274.0,
#   275.0,
#   273.0,
#   268.0,
#   284.0,
#   297.0,
#   288.0,
#   282.0,
#   268.0,
#   268.0,
#   270.0,
#   270.0,
#   266.0,
#   262.0,
#   259.0,
#   253.0,
#   240.0,
#   233.0,
#   226.0,
#   223.0,
#   217.0,
#   208.0,
#   200.0,
#   192.0,
#   185.0,
#   179.0,
#   171.0,
#   166.0,
#   160.0,
#   154.0,
#   148.0,
#   141.0,
#   133.0,
#   142.0,
#   171.0,
#   170.0,
#   169.0,
#   160.0,
#   150.0,
#   141.0,
#   135.0,
#   130.0,
#   125.0,
#   119.0,
#   113.0,
#   108.0,
#   102.0,
#   95.0,
#   88.0,
#   80.0,
#   73.0,
#   67.0,
#   62.0,
#   58.0,
#   56.0,
#   54.0,
#   52.0,
#   50.0,
#   49.0,
#   48.0,
#   47.0,
#   46.0,
#   45.0,
#   45.0,
#   45.0,
#   45.0,
#   45.0,
#   44.0,
#   44.0,
#   46.0,
#   46.0,
#   45.0,
#   45.0,
#   45.0,
#   45.0,
#   46.0,
#   48.0,
#   48.0,
#   49.0,
#   81.0,
#   114.0,
#   103.0,
#   110.0,
#   114.0,
#   117.0,
#   119.0,
#   125.0,
#   132.0,
#   139.0,
#   144.0,
#   143.0,
#   154.0,
#   163.0,
#   162.0,
#   160.0,
#   160.0,
#   158.0,
#   160.0,
#   160.0,
#   157.0,
#   160.0,
#   160.0,
#   157.0,
#   156.0,
#   172.0,
#   206.0,
#   221.0,
#   237.0,
#   255.0,
#   264.0,
#   280.0,
#   289.0,
#   289.0,
#   291.0,
#   289.0,
#   282.0,
#   274.0,
#   267.0,
#   263.0,
#   257.0,
#   248.0,
#   227.0,
#   218.0,
#   213.0,
#   204.0,
#   195.0,
#   203.0,
#   224.0,
#   199.0,
#   192.0,
#   185.0,
#   184.0,
#   187.0,
#   188.0,
#   184.0,
#   188.0,
#   195.0,
#   197.0,
#   193.0,
#   189.0,
#   188.0,
#   189.0,
#   194.0,
#   198.0,
#   193.0,
#   197.0,
#   206.0,
#   206.0,
#   206.0,
#   202.0,
#   198.0,
#   205.0,
#   215.0,
#   217.0,
#   216.0,
#   212.0,
#   215.0,
#   211.0,
#   210.0,
#   216.0,
#   220.0,
#   221.0,
#   225.0,
#   225.0,
#   236.0,
#   235.0,
#   237.0,
#   239.0,
#   235.0,
#   232.0,
#   237.0,
#   244.0,
#   249.0,
#   248.0,
#   247.0,
#   244.0,
#   243.0,
#   239.0,
#   241.0,
#   239.0,
#   235.0,
#   242.0,
#   249.0,
#   251.0,
#   241.0,
#   239.0,
#   237.0,
#   232.0,
#   225.0,
#   221.0,
#   224.0,
#   227.0,
#   217.0,
#   199.0,
#   184.0,
#   175.0,
#   172.0,
#   182.0,
#   186.0,
#   185.0,
#   185.0,
#   186.0,
#   195.0,
#   204.0,
#   210.0,
#   214.0,
#   218.0,
#   220.0,
#   221.0,
#   222.0,
#   222.0,
#   221.0,
#   217.0,
#   218.0,
#   215.0,
#   209.0,
#   205.0,
#   194.0,
#   184.0,
#   180.0,
#   177.0,
#   175.0,
#   175.0,
#   176.0,
#   179.0,
#   184.0,
#   200.0,
#   211.0,
#   216.0,
#   219.0,
#   220.0,
#   223.0,
#   229.0,
#   222.0,
#   222.0,
#   225.0,
#   213.0,
#   199.0,
#   189.0,
#   172.0,
#   160.0,
#   151.0,
#   138.0,
#   128.0,
#   116.0,
#   109.0,
#   100.0,
#   89.0,
#   85.0,
#   82.0,
#   83.0,
#   90.0,
#   95.0,
#   99.0,
#   103.0,
#   108.0,
#   110.0,
#   107.0,
#   108.0,
#   111.0,
#   108.0,
#   106.0,
#   105.0,
#   104.0,
#   104.0,
#   106.0,
#   107.0,
#   104.0,
#   103.0,
#   103.0,
#   103.0,
#   104.0,
#   107.0,
#   112.0,
#   115.0,
#   118.0,
#   118.0,
#   119.0,
#   121.0,
#   126.0,
#   129.0,
#   134.0,
#   140.0,
#   141.0,
#   141.0,
#   143.0,
#   147.0,
#   148.0,
#   149.0,
#   150.0,
#   151.0,
#   151.0,
#   152.0,
#   153.0,
#   155.0,
#   159.0,
#   162.0,
#   164.0,
#   167.0,
#   170.0,
#   172.0,
#   174.0,
#   173.0,
#   172.0,
#   172.0],
#  [169.0,
#   170.0,
#   166.0,
#   163.0,
#   160.0,
#   158.0,
#   156.0,
#   154.0,
#   152.0,
#   147.0,
#   145.0,
#   149.0,
#   161.0,
#   166.0,
#   174.0,
#   150.0,
#   147.0,
#   157.0,
#   169.0,
#   176.0,
#   187.0,
#   194.0,
#   188.0,
#   181.0,
#   172.0,
#   162.0,
#   153.0,
#   145.0,
#   137.0,
#   129.0,
#   121.0,
#   113.0,
#   105.0,
#   99.0,
#   93.0,
#   88.0,
#   87.0,
#   93.0,
#   104.0,
#   114.0,
#   109.0,
#   115.0,
#   116.0,
#   113.0,
#   109.0,
#   106.0,
#   107.0,
#   104.0,
#   102.0,
#   98.0,
#   93.0,
#   84.0,
#   77.0,
#   73.0,
#   71.0,
#   74.0,
#   82.0,
#   86.0,
#   92.0,
#   100.0,
#   108.0,
#   120.0,
#   135.0,
#   142.0,
#   147.0,
#   153.0,
#   156.0,
#   156.0,
#   158.0,
#   158.0,
#   158.0,
#   159.0,
#   158.0,
#   158.0,
#   157.0,
#   156.0,
#   155.0,
#   150.0,
#   148.0,
#   146.0,
#   146.0,
#   145.0,
#   141.0,
#   140.0,
#   139.0,
#   137.0,
#   135.0,
#   134.0,
#   137.0,
#   137.0,
#   135.0,
#   131.0,
#   125.0,
#   119.0,
#   112.0,
#   106.0,
#   105.0,
#   105.0,
#   111.0,
#   117.0,
#   115.0,
#   113.0,
#   112.0,
#   112.0,
#   112.0,
#   113.0,
#   107.0,
#   104.0,
#   101.0,
#   101.0,
#   101.0,
#   103.0,
#   104.0,
#   102.0,
#   101.0,
#   106.0,
#   109.0,
#   112.0,
#   113.0,
#   114.0,
#   114.0,
#   114.0,
#   113.0,
#   112.0,
#   113.0,
#   114.0,
#   114.0,
#   115.0,
#   116.0,
#   121.0,
#   123.0,
#   122.0,
#   118.0,
#   115.0,
#   115.0,
#   119.0,
#   122.0,
#   123.0,
#   123.0,
#   123.0,
#   121.0,
#   120.0,
#   118.0,
#   118.0,
#   117.0,
#   116.0,
#   113.0,
#   109.0,
#   107.0,
#   107.0,
#   105.0,
#   103.0,
#   104.0,
#   107.0,
#   109.0,
#   112.0,
#   115.0,
#   116.0,
#   116.0,
#   118.0,
#   120.0,
#   121.0,
#   121.0,
#   123.0,
#   126.0,
#   128.0,
#   130.0,
#   130.0,
#   126.0,
#   125.0,
#   126.0,
#   126.0,
#   121.0,
#   119.0,
#   125.0,
#   129.0,
#   134.0,
#   141.0,
#   146.0,
#   152.0],
#  [178.0,
#   182.0,
#   185.0,
#   187.0,
#   188.0,
#   190.0,
#   191.0,
#   190.0,
#   190.0,
#   191.0,
#   191.0,
#   186.0,
#   183.0,
#   184.0,
#   187.0,
#   193.0,
#   196.0,
#   197.0,
#   198.0,
#   199.0,
#   199.0,
#   198.0,
#   195.0,
#   191.0,
#   189.0,
#   188.0,
#   190.0,
#   189.0,
#   186.0,
#   182.0,
#   179.0,
#   176.0,
#   173.0,
#   168.0,
#   164.0,
#   162.0,
#   162.0,
#   160.0,
#   157.0,
#   155.0,
#   153.0,
#   151.0,
#   150.0,
#   149.0,
#   148.0,
#   146.0,
#   141.0,
#   136.0,
#   132.0,
#   128.0,
#   126.0,
#   123.0,
#   121.0,
#   119.0,
#   117.0,
#   115.0,
#   112.0,
#   109.0,
#   106.0,
#   104.0,
#   102.0,
#   100.0,
#   99.0,
#   98.0,
#   97.0,
#   95.0,
#   99.0,
#   100.0,
#   100.0,
#   99.0,
#   99.0,
#   99.0,
#   99.0,
#   99.0,
#   97.0,
#   94.0,
#   93.0,
#   93.0,
#   93.0,
#   91.0,
#   89.0,
#   88.0,
#   87.0,
#   87.0,
#   87.0,
#   89.0,
#   90.0,
#   89.0,
#   89.0,
#   89.0,
#   89.0,
#   89.0,
#   93.0,
#   94.0,
#   90.0,
#   90.0,
#   89.0,
#   89.0,
#   94.0,
#   98.0,
#   98.0,
#   97.0,
#   97.0,
#   97.0,
#   98.0,
#   94.0,
#   91.0,
#   95.0,
#   106.0,
#   109.0,
#   111.0,
#   117.0,
#   124.0,
#   128.0,
#   134.0,
#   143.0,
#   157.0,
#   168.0,
#   177.0,
#   181.0,
#   171.0,
#   171.0,
#   176.0,
#   181.0,
#   183.0,
#   188.0,
#   192.0,
#   194.0,
#   194.0,
#   195.0,
#   203.0,
#   238.0,
#   225.0,
#   218.0,
#   215.0,
#   202.0,
#   209.0,
#   215.0,
#   210.0,
#   205.0,
#   205.0,
#   197.0,
#   185.0,
#   184.0,
#   189.0,
#   188.0,
#   181.0,
#   173.0,
#   162.0,
#   155.0,
#   167.0,
#   165.0,
#   167.0,
#   165.0,
#   163.0,
#   161.0,
#   159.0,
#   158.0,
#   156.0,
#   152.0,
#   148.0,
#   136.0,
#   134.0,
#   122.0,
#   110.0,
#   107.0,
#   107.0,
#   103.0,
#   99.0,
#   95.0,
#   94.0,
#   93.0,
#   95.0,
#   99.0,
#   104.0,
#   108.0,
#   110.0,
#   109.0,
#   106.0,
#   104.0,
#   100.0,
#   98.0,
#   97.0,
#   97.0,
#   95.0,
#   93.0,
#   92.0,
#   97.0,
#   107.0,
#   118.0,
#   120.0,
#   127.0,
#   139.0,
#   151.0,
#   155.0,
#   155.0,
#   160.0,
#   169.0,
#   177.0,
#   179.0,
#   179.0,
#   187.0,
#   193.0,
#   196.0,
#   201.0,
#   204.0,
#   197.0,
#   200.0,
#   202.0,
#   213.0,
#   215.0,
#   212.0,
#   213.0,
#   212.0,
#   211.0,
#   211.0,
#   213.0,
#   220.0,
#   223.0,
#   223.0,
#   224.0,
#   220.0,
#   215.0,
#   213.0,
#   214.0,
#   217.0,
#   219.0,
#   223.0,
#   221.0,
#   219.0,
#   215.0,
#   211.0,
#   213.0,
#   216.0,
#   215.0,
#   211.0,
#   211.0,
#   208.0,
#   207.0,
#   211.0,
#   208.0,
#   208.0,
#   206.0,
#   207.0,
#   208.0,
#   207.0,
#   200.0,
#   192.0,
#   191.0,
#   190.0,
#   191.0,
#   191.0,
#   192.0,
#   199.0,
#   197.0,
#   191.0,
#   185.0,
#   180.0,
#   179.0,
#   177.0,
#   170.0,
#   171.0,
#   172.0,
#   173.0,
#   177.0,
#   183.0,
#   191.0,
#   197.0,
#   200.0,
#   201.0,
#   196.0,
#   198.0,
#   198.0,
#   196.0,
#   200.0,
#   195.0,
#   189.0,
#   183.0,
#   177.0,
#   171.0,
#   162.0,
#   154.0,
#   146.0,
#   132.0,
#   123.0,
#   119.0,
#   113.0,
#   108.0,
#   100.0,
#   95.0,
#   91.0,
#   91.0,
#   94.0,
#   101.0,
#   108.0,
#   117.0,
#   124.0,
#   128.0,
#   127.0,
#   126.0,
#   123.0,
#   115.0,
#   110.0,
#   111.0,
#   112.0,
#   117.0,
#   123.0,
#   126.0,
#   126.0,
#   125.0,
#   125.0,
#   128.0,
#   133.0,
#   137.0,
#   140.0,
#   142.0,
#   142.0,
#   143.0,
#   144.0,
#   145.0,
#   147.0,
#   148.0,
#   148.0,
#   148.0,
#   148.0,
#   148.0,
#   149.0,
#   150.0,
#   152.0,
#   155.0,
#   156.0,
#   158.0,
#   161.0,
#   164.0,
#   168.0,
#   172.0,
#   176.0]]
